# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as rc

# # Apple
# rc('font', family='Gothic')
# plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt


anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_I = anscombe[anscombe['dataset'] == "I"]
dataset_II = anscombe[anscombe['dataset'] == "II"]
dataset_III = anscombe[anscombe['dataset'] == "III"]
dataset_IV = anscombe[anscombe['dataset'] == "IV"]
dataset_I
# 이 형식 기억해!
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_I['x'], dataset_I['y'])

# %%
plt.plot(dataset_I['x'], dataset_I['y'], 'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_I['x'], dataset_I['y'], 'o')
axes2.plot(dataset_II['x'], dataset_II['y'], 'o')
axes3.plot(dataset_III['x'], dataset_III['y'], 'o')
axes4.plot(dataset_IV['x'], dataset_IV['y'], 'o')
fig

# %%
df = sns.load_dataset('anscombe')
x_mean = df.groupby('dataset')[['x','y']].mean()
x_mean
dat_std = df.groupby('dataset')[['x', 'y']].std()
x_mean
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
dat_std
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %%
import seaborn as sns
import pandas as pd
anscombe = sns.load_dataset("anscombe")
x_mean = anscombe.groupby(['x']).mean()
y_mean = anscombe.groupby(['y']).mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_17904\3124668755.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x_mean = anscombe.groupby(['x']).mean()
# C:\Users\starl\AppData\Local\Temp\ipykernel_17904\3124668755.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   y_mean = anscombe.groupby(['y']).mean()

# %%
x_mean
# Out:
#               y
# x
# 4.0    4.250000
# 5.0    5.383333
# 6.0    6.483333
# 7.0    6.166667
# 8.0    7.066923
# 9.0    8.230000
# 10.0   8.213333
# 11.0   8.466667
# 12.0   9.373333
# 13.0   9.686667
# 14.0   8.966667
# 19.0  12.500000

# %%
y_mean
# Out:
#           x
# y
# 3.10    4.0
# 4.26    4.0
# 4.74    5.0
# 4.82    7.0
# 5.25    8.0
# 5.39    4.0
# 5.56    8.0
# 5.68    5.0
# 5.73    5.0
# 5.76    8.0
# 6.08    6.0
# 6.13    6.0
# 6.42    7.0
# 6.58    8.0
# 6.77    8.0
# 6.89    8.0
# 6.95    8.0
# 7.04    8.0
# 7.11    9.0
# 7.24    6.0
# 7.26    7.0
# 7.46   10.0
# 7.58   13.0
# 7.71    8.0
# 7.81   11.0
# 7.91    8.0
# 8.04   10.0
# 8.10   14.0
# 8.14    8.0
# 8.15   12.0
# 8.33   11.0
# 8.47    8.0
# 8.74   13.0
# 8.77    9.0
# 8.81    9.0
# 8.84   11.0
# 9.13   12.0
# 9.14   10.0
# 9.26   11.0
# 9.96   14.0
# 10.84  12.0
# 12.50  19.0
# 12.74  13.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df1 = df[df['dataset'] == 'I']
df2 = df[df['dataset'] == 'II']
df3 = df[df['dataset'] == 'III']
df4 = df[df['dataset'] == 'IV']
df1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(df1['x'], df1['y'])

# %%
plt.plot(df1['x'], df1['y'], '*')
# x축에는 x값, y값에는 y값

# %%
fig.add_subplot(1, 1, 1)
fig = plt.figure()
axes11 = fig.add_subplot(2, 2, 1)
axes21 = fig.add_subplot(2, 2, 2)
axes31 = fig.add_subplot(2, 2, 3)
axes41 = fig.add_subplot(2, 2, 4)

axes11.plot(df1['x'], df1['y'], 'o')
axes21.plot(df2['x'], df2['y'], 'o')
axes31.plot(df3['x'], df3['y'], 'o')
axes41.plot(df4['x'], df4['y'], 'o')
fig

# %%
axes11.set_title("data1")
axes21.set_title("data2")
axes31.set_title("data3")
axes41.set_title("data4")
fig

# %%
fig.suptitle("dataset view")
# Out:
# Text(0.5, 0.98, 'dataset view')

# %%
fig.tight_layout()
fig

# %%
tips = sns.load_dataset("tips")
tips.head()
print(type(tips))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.tail()
# 각 요일별 식당의 전체 비용, 성별, 팁, 식사 파트, 타임 -> 사람의 수
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)

# %%
fig = plt.figure()
# x = total_bill , y = tip
axes1 = fig.add_subplot(1, 1, 1)
axes1.plot(tips['total_bill'], tips['tip'], '*', color="pink")
axes1.set_title("x = total_bill, y = tip")
axes1.set_xlabel("total_bill")
axes1.set_ylabel("bill")
# Out:
# Text(0, 0.5, 'bill')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.hist(tips['total_bill'], bins=10, color="pink")
axes1.set_title("Histogram of Total Bill")
axes1.set_xlabel("Total Bill")
axes1.set_ylabel("Frequency")
fig

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'], color="pink", marker="*")
axes1.set_title("Scatter PLOT!")
axes1.set_xlabel("total bill")
axes1.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
tips[tips['sex'] == 'Female'][['tip', 'total_bill']]
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 4    3.61       24.59
# 11   5.00       35.26
# 14   3.02       14.83
# 16   1.67       10.33
# ..    ...         ...
# 226  2.00       10.09
# 229  2.88       22.12
# 238  4.67       35.83
# 240  2.00       27.18
# 243  3.00       18.78
#
# [87 rows x 2 columns]

# %%
tips[tips['sex'] == 'Male'].head()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.boxplot([tips[tips['sex'] == 'Female']['tip'], tips[tips['sex'] == 'Male']['tip']], labels=['Female', 'Male'])
axes1.set_title("Boxplot of Tips by Sex")
axes1.set_xlabel("Sex")
axes1.set_ylabel("Tip")
fig

# %%
def record_sex(sex):
    if sex == "Female":
        return 0
    else:
        return 1

# %%
tips.head()

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# tips['sex_color'] = tips['sex'].apply(record_sex)
tips['sex_color'] = tips['sex'].apply(record_sex)

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'], tips['size'] * 10, tips['sex_color'], alpha=0.5)

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = plt.subplots()
ax = sns.distplot(tips['size'])
ax.set_title("Total Bill Histogram With Density Plot")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\4225966701.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['size'])
# Text(0.5, 1.0, 'Total Bill Histogram With Density Plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title("Total Bill Histogram With Density Plot")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\3677541153.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram With Density Plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title("Total Bill Histogram With Density Plot")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_ylabel("Frequency")
ax.set_xlabel("Total Bill")
ax.set_title("Total Bill Histogram With Density Plot")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\3496156158.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0.5, 1.0, 'Total Bill Histogram With Density Plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title("Total Bill Histogram With Density Plot")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\232269127.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0.5, 1.0, 'Total Bill Histogram With Density Plot')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_ylabel("Frequency")
ax.set_xlabel("Total Bill")
ax.set_title("Total Bill Histogram With RUG Plot")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\1450510945.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 1.0, 'Total Bill Histogram With RUG Plot')

# %%
ax = plt.subplots()
ax = sns.countplot(x='day', data=tips)
ax.set_title("Count of days")
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax = plt.subplots()
ax = sns.countplot(x='size', data=tips)
ax.set_title("Count of days")
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.countplot(x='time', data=tips)
ax.set_title("Count of days")
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.countplot(x='sex', data=tips)
ax.set_title("Count of days")
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title("Scatter Plot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips , fit_reg=False)
ax.set_title("Scatter Plot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total  Bill', ylabel="Tip")
joint.fig.suptitle("Joint plot")
# Out:
# Text(0.5, 0.98, 'Joint plot')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
joint.set_axis_labels(xlabel='Total  Bill', ylabel="Tip")
joint.fig.suptitle("Joint plot")
# Out:
# Text(0.5, 0.98, 'Joint plot')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', color='pink')
joint.set_axis_labels(xlabel='Total  Bill', ylabel="Tip")
joint.fig.suptitle("Joint plot")
# Out:
# Text(0.5, 0.98, 'Joint plot')

# %%
ax = plt.subplots()
ax = sns.kdeplot(x="total_bill", y='tip', data=tips)
ax.set_title('Kernal Density plot of Total Bill and tip')
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.kdeplot(x="total_bill", y='tip', data=tips, shade=True)
ax.set_title('Kernal Density plot of Total Bill and tip')
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_13712\2768981813.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x="total_bill", y='tip', data=tips, shade=True)
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time Of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='day', y='total_bill', data=tips)
ax.set_title('Boxplot of day total_bill')
ax.set_xlabel('Time of day')
ax.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='size', y='total_bill', data=tips)
ax.set_title('Boxplot of size and total bill')
ax.set_xlabel('Time of day')
ax.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('violin plot')
ax.set_xalbel('Time of day')
ax.set_ylabel('total bill')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       2 ax = sns.violinplot(x='time', y='total_bill', data=tips)
#       3 ax.set_title('violin plot')
# ----> 4 ax.set_xalbel('Time of day')
#       5 ax.set_ylabel('total bill')
#
# AttributeError: 'Axes' object has no attribute 'set_xalbel'

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
ax = plt.subplots()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
plt.show()
# lmplot-> 리니어 선형모델\

# %%
ax = plt.subplots()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False, markers=['o','x'])
plt.show()
# lmplot-> 리니어 선형모델\

# %%
ax = plt.subplots()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, col='day')
plt.show()
# lmplot-> 리니어 선형모델\

# %%
ax = plt.subplots()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False, palette='set2')
plt.show()
# lmplot-> 리니어 선형모델\
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File ~\anaconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\cm.py:82, in ColormapRegistry.__getitem__(self, item)
#      81 except KeyError:
# ...

# %%
ax = plt.subplots()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', fit_reg=False)
plt.show()
# lmplot-> 리니어 선형모델\

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, scatter_kws = {'s' : 50})

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax, gridsize=10)
