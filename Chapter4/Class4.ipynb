# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as rc

# # Apple
# rc('font', family='Gothic')
# plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt


anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset_I = anscombe[anscombe['dataset'] == "I"]
dataset_II = anscombe[anscombe['dataset'] == "II"]
dataset_III = anscombe[anscombe['dataset'] == "III"]
dataset_IV = anscombe[anscombe['dataset'] == "IV"]
dataset_I
# 이 형식 기억해!
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_I['x'], dataset_I['y'])

# %%
plt.plot(dataset_I['x'], dataset_I['y'], 'o')

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_I['x'], dataset_I['y'], 'o')
axes2.plot(dataset_II['x'], dataset_II['y'], 'o')
axes3.plot(dataset_III['x'], dataset_III['y'], 'o')
axes4.plot(dataset_IV['x'], dataset_IV['y'], 'o')
fig

# %%
import seaborn as sns
import pandas as pd
anscombe = sns.load_dataset("anscombe")
x_mean = anscombe.groupby(['x']).mean()
y_mean = anscombe.groupby(['y']).mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_2796\3124668755.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x_mean = anscombe.groupby(['x']).mean()
# C:\Users\starl\AppData\Local\Temp\ipykernel_2796\3124668755.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   y_mean = anscombe.groupby(['y']).mean()

# %%
x_mean
# Out:
#               y
# x
# 4.0    4.250000
# 5.0    5.383333
# 6.0    6.483333
# 7.0    6.166667
# 8.0    7.066923
# 9.0    8.230000
# 10.0   8.213333
# 11.0   8.466667
# 12.0   9.373333
# 13.0   9.686667
# 14.0   8.966667
# 19.0  12.500000

# %%
y_mean
# Out:
#           x
# y
# 3.10    4.0
# 4.26    4.0
# 4.74    5.0
# 4.82    7.0
# 5.25    8.0
# 5.39    4.0
# 5.56    8.0
# 5.68    5.0
# 5.73    5.0
# 5.76    8.0
# 6.08    6.0
# 6.13    6.0
# 6.42    7.0
# 6.58    8.0
# 6.77    8.0
# 6.89    8.0
# 6.95    8.0
# 7.04    8.0
# 7.11    9.0
# 7.24    6.0
# 7.26    7.0
# 7.46   10.0
# 7.58   13.0
# 7.71    8.0
# 7.81   11.0
# 7.91    8.0
# 8.04   10.0
# 8.10   14.0
# 8.14    8.0
# 8.15   12.0
# 8.33   11.0
# 8.47    8.0
# 8.74   13.0
# 8.77    9.0
# 8.81    9.0
# 8.84   11.0
# 9.13   12.0
# 9.14   10.0
# 9.26   11.0
# 9.96   14.0
# 10.84  12.0
# 12.50  19.0
# 12.74  13.0
