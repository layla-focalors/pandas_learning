# %%
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips.head())
# 지불 금액, 팁, 성별, 흡연 유무, 요일, 시간, 전체 인원 정보를 저장한다.!!
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 변수 하나 : 일변량
# 변수 여러개 : 다변량
import matplotlib.pyplot as plt
fig = plt.figure()

axes1 = fig.add_subplot(1, 1, 1)
axes1.hist(tips['total_bill'], bins=10)
axes1.set_xlabel("Frequency")
axes1.set_ylabel("Total Bills")
# Out:
# Text(0, 0.5, 'Total Bills')

# %%
scatter = plt.figure()
axes2 = scatter.add_subplot(1, 1, 1)
axes2.scatter(tips['total_bill'], tips['tip'])
axes2.set_title("Scatterplot of Total Bill vs Tips")
axes2.set_xlabel("Total Bill")
axes2.set_ylabel("Tip")
# 이산형 변수 : Female, Male과 같이 명확히 구분되는 값
# 연속형 변수 : tip과 같이 정확히 셀 수 없는 것
# Out:
# Text(0, 0.5, 'Tip')

# %%
box_plot = plt.figure()
axes1 = box_plot.add_subplot(1, 1, 1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'], tips[tips['sex'] == 'Male']['tip']], labels=['Female', 'Male'])
axes1.set_title("Boxplot od Tips by SEX")
axes1.set_xlabel("Sex")
axes1.set_ylabel("Tip")
# 데이터 입력 시 여러 개의 데이터를 입력하기에 " [ ] "안에 입력 필수에요!
# Out:
# Text(0, 0.5, 'Tip')
