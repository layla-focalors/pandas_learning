# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2023, 12, 15, 18, 39, 7, 537549)

# %%
now1 = datetime.datetime.now()
now1
# Out:
# datetime.datetime(2023, 12, 15, 18, 39, 24, 443280)

# %%
print(now1)
# Out:
# 2023-12-15 18:39:24.443280

# %%
now2 = datetime.datetime.today()

# %%
now2
# Out:
# datetime.datetime(2023, 12, 15, 18, 39, 42, 414879)

# %%
print(now2)
# Out:
# 2023-12-15 18:39:42.414879

# %%
t1 = datetime.datetime.now()
t2= datetime.datetime(1970, 1, 1)
t3 = datetime.datetime(1970, 12, 12, 13, 24, 34)

# %%
dat = [t1, t2, t3]
for i in dat:
    print(i)
# Out:
# 2023-12-15 18:42:01.978439
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %%
diff1 = t1 - t2

# %%
diff1
# Out:
# datetime.timedelta(days=19706, seconds=67321, microseconds=978439)

# %%
print(diff1)
# Out:
# 19706 days, 18:42:01.978439

# %%
print(type(diff1))
# Out:
# <class 'datetime.timedelta'>

# %%
diff2 = t2 - t1

# %%
print(diff2)
# Out:
# -19707 days, 5:17:58.021561

# %%
print(type(diff2))
# Out:
# <class 'datetime.timedelta'>

# %%
import pandas as pd

# %%
import os

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df.Date = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df['date_dt'] = pd.to_datetime(df['Date'])

# %%
df[['Date','date_dt']]
# Out:
#           Date    date_dt
# 0   2015-01-05 2015-01-05
# 1   2015-01-04 2015-01-04
# 2   2015-01-03 2015-01-03
# 3   2015-01-02 2015-01-02
# 4   2014-12-31 2014-12-31
# ..         ...        ...
# 117 2014-03-27 2014-03-27
# 118 2014-03-26 2014-03-26
# 119 2014-03-25 2014-03-25
# 120 2014-03-24 2014-03-24
# 121 2014-03-22 2014-03-22
#
# [122 rows x 2 columns]

# %%
df = pd.DataFrame({
    'order_day' : ['01/01/15','02/01/15','03/01/15']
})

# %%
df
# Out:
#   order_day
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15

# %%
df['date_dt2'] = pd.to_datetime(df['order_day'], format='%d/%m/%y')

# %%
df
# Out:
#   order_day   date_dt2
# 0  01/01/15 2015-01-01
# 1  02/01/15 2015-01-02
# 2  03/01/15 2015-01-03

# %%
df['date_dt3'] = pd.to_datetime(df['order_day'], format='%m/%d/%y')
df['date_dt4'] = pd.to_datetime(df['order_day'], format='%y/%m/%d')

# %%
df
# Out:
#   order_day   date_dt2   date_dt3   date_dt4
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   order_day  3 non-null      object
#  1   date_dt2   3 non-null      datetime64[ns]
#  2   date_dt3   3 non-null      datetime64[ns]
#  3   date_dt4   3 non-null      datetime64[ns]
# dtypes: datetime64[ns](3), object(1)
# memory usage: 228.0+ bytes

# %%
now = datetime.datetime.now()

# %%
now
# Out:
# datetime.datetime(2023, 12, 15, 18, 47, 40, 267412)

# %%
print(now)
# Out:
# 2023-12-15 18:47:40.267412

# %%
nowDate = now.strftime('%Y-%m-%d')

# %%
print(nowDate)
# Out:
# 2023-12-15

# %%
print(now.strftime('%H:%M:%S'))
# Out:
# 18:47:40

# %%
print(now.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2023-12-15 18:47:40

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
date_series = pd.Series(['2018-05-16','2018-05-17','2018-05-18'])

# %%
date_series
# Out:
# 0    2018-05-16
# 1    2018-05-17
# 2    2018-05-18
# dtype: object

# %%
d1 = pd.to_datetime(date_series)

# %%
d1
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[ns]

# %%
d1[0].year
# Out:
# 2018

# %%
d1[0].month
# Out:
# 5

# %%
d1[0].day
# Out:
# 16

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df['date_dt'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df[['Date','date_dt']].head()
# Out:
#         Date    date_dt
# 0 2015-01-05 2015-01-05
# 1 2015-01-04 2015-01-04
# 2 2015-01-03 2015-01-03
# 3 2015-01-02 2015-01-02
# 4 2014-12-31 2014-12-31

# %%
df['year'] = df['Date'].dt.year

# %%
df['month'], df['day'] = df['Date'].dt.month, df['Date'].dt.day

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df[['Date','month','year', 'day']]
# Out:
#           Date  month  year  day
# 0   2015-01-05      1  2015    5
# 1   2015-01-04      1  2015    4
# 2   2015-01-03      1  2015    3
# 3   2015-01-02      1  2015    2
# 4   2014-12-31     12  2014   31
# ..         ...    ...   ...  ...
# 117 2014-03-27      3  2014   27
# 118 2014-03-26      3  2014   26
# 119 2014-03-25      3  2014   25
# 120 2014-03-24      3  2014   24
# 121 2014-03-22      3  2014   22
#
# [122 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df.tail()
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  ...  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# 117         NaN  ...                 5.0             NaN             NaN
# ...

# %%
df.iloc[-5:, :5]
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %%
df.tail(1)
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  ...  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# 121         NaN  ...                 NaN             NaN             NaN
#
#      Deaths_UnitedStates  Deaths_Spain  Deaths_Mali    date_dt  year month  \
# 121                  NaN           NaN          NaN 2014-03-22  2014     3
#
#      day
# 121   22
#
# [1 rows x 22 columns]

# %%
df['date_dt'].min()
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
type(df['date_dt'].min())
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    ...  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# ...

# %%
df['outbreak_d'] = df['date_dt'] - df['date_dt'].min()

# %%
df['outbreak_d']
# Out:
# 0     289 days
# 1     288 days
# 2     287 days
# 3     286 days
# 4     284 days
#         ...
# 117     5 days
# 118     4 days
# 119     3 days
# 120     2 days
# 121     0 days
# Name: outbreak_d, Length: 122, dtype: timedelta64[ns]

# %%
df[['Date','Day','outbreak_d']]
# Out:
#           Date  Day outbreak_d
# 0   2015-01-05  289   289 days
# 1   2015-01-04  288   288 days
# 2   2015-01-03  287   287 days
# 3   2015-01-02  286   286 days
# 4   2014-12-31  284   284 days
# ..         ...  ...        ...
# 117 2014-03-27    5     5 days
# 118 2014-03-26    4     4 days
# 119 2014-03-25    3     3 days
# 120 2014-03-24    2     2 days
# 121 2014-03-22    0     0 days
#
# [122 rows x 3 columns]

# %%
df = pd.read_csv('../data/banklist.csv', parse_dates=[5, 6])

# %%
df
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
df.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05

# %%
df.tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 550                 Superior Bank, FSB    Hinsdale  IL  32646
# 551                Malta National Bank       Malta  OH   6629
# 552    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 553  National State Bank of Metropolis  Metropolis  IL   3815
# 554                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 550                Superior Federal, FSB   2001-07-27   2014-08-19
# 551                    North Valley Bank   2001-05-03   2002-11-18
# 552  Southern New Hampshire Bank & Trust   2001-02-02   2003-02-18
# 553              Banterra Bank of Marion   2000-12-14   2005-03-17
# 554                   Bank of the Orient   2000-10-13   2005-03-17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    datetime64[ns]
#  6   Updated Date           555 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB

# %%
df['closing_quarter'], df['closing_years'] = df['Closing Date'].dt.quarter, df['Closing Date'].dt.year

# %%
df[['Closing Date','closing_quarter','closing_years']]
# Out:
#     Closing Date  closing_quarter  closing_years
# 0     2017-12-15                4           2017
# 1     2017-10-13                4           2017
# 2     2017-05-26                2           2017
# 3     2017-05-05                2           2017
# 4     2017-04-28                2           2017
# ..           ...              ...            ...
# 550   2001-07-27                3           2001
# 551   2001-05-03                2           2001
# 552   2001-02-02                1           2001
# 553   2000-12-14                4           2000
# 554   2000-10-13                4           2000
#
# [555 rows x 3 columns]

# %%
df.groupby('closing_years').size()
# Out:
# closing_years
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %%
df.groupby(['closing_years','closing_quarter']).size()
# Out:
# closing_years  closing_quarter
# 2000           4                   2
# 2001           1                   1
#                2                   1
#                3                   2
# 2002           1                   6
#                2                   2
#                3                   1
#                4                   2
# 2003           1                   1
#                2                   1
#                4                   1
# 2004           1                   3
#                2                   1
# 2007           1                   1
#                3                   1
#                4                   1
# 2008           1                   2
#                2                   2
#                3                   9
#                4                  12
# 2009           1                  21
#                2                  24
#                3                  50
#                4                  45
# ...

# %%
df.groupby('closing_years').size().plot()
# Out:
# <Axes: xlabel='closing_years'>

# %%
df.groupby(['closing_years','closing_quarter']).size().plot()
# Out:
# <Axes: xlabel='closing_years,closing_quarter'>

# %%
df = pd.read_csv('../data/tesla_stock_quandle.csv', parse_dates=['Date'])

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2010-06-29   1.266667   1.666667   1.169333   1.592667   1.592667
# 1    2010-06-30   1.719333   2.028000   1.553333   1.588667   1.588667
# 2    2010-07-01   1.666667   1.728000   1.351333   1.464000   1.464000
# 3    2010-07-02   1.533333   1.540000   1.247333   1.280000   1.280000
# 4    2010-07-06   1.333333   1.333333   1.055333   1.074000   1.074000
# ...         ...        ...        ...        ...        ...        ...
# 1944 2018-03-20  20.991333  21.083332  20.584000  20.703333  20.703333
# 1945 2018-03-21  20.683332  21.496000  20.679333  21.101999  21.101999
# 1946 2018-03-22  20.926001  21.254667  20.545334  20.606667  20.606667
# 1947 2018-03-23  20.750000  20.750000  20.030001  20.102667  20.102667
# 1948 2018-03-26  20.489332  20.506001  19.424000  20.278667  20.278667
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1949 non-null   datetime64[ns]
#  1   Open       1949 non-null   float64
#  2   High       1949 non-null   float64
#  3   Low        1949 non-null   float64
#  4   Close      1949 non-null   float64
#  5   Adj Close  1949 non-null   float64
#  6   Volume     1949 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 106.7 KB

# %%
df[(df['Date'].dt.year == 2010) & (df['Date'].dt.month == 6)]
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500

# %%
df.index = df.Date

# %%
df
# Out:
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2010-06-29 2010-06-29   1.266667   1.666667   1.169333   1.592667   1.592667
# 2010-06-30 2010-06-30   1.719333   2.028000   1.553333   1.588667   1.588667
# 2010-07-01 2010-07-01   1.666667   1.728000   1.351333   1.464000   1.464000
# 2010-07-02 2010-07-02   1.533333   1.540000   1.247333   1.280000   1.280000
# 2010-07-06 2010-07-06   1.333333   1.333333   1.055333   1.074000   1.074000
# ...               ...        ...        ...        ...        ...        ...
# 2018-03-20 2018-03-20  20.991333  21.083332  20.584000  20.703333  20.703333
# 2018-03-21 2018-03-21  20.683332  21.496000  20.679333  21.101999  21.101999
# 2018-03-22 2018-03-22  20.926001  21.254667  20.545334  20.606667  20.606667
# 2018-03-23 2018-03-23  20.750000  20.750000  20.030001  20.102667  20.102667
# 2018-03-26 2018-03-26  20.489332  20.506001  19.424000  20.278667  20.278667
#
#                Volume
# Date
# ...

# %%
df.iloc[:5, :5]
# Out:
#                  Date      Open      High       Low     Close
# Date
# 2010-06-29 2010-06-29  1.266667  1.666667  1.169333  1.592667
# 2010-06-30 2010-06-30  1.719333  2.028000  1.553333  1.588667
# 2010-07-01 2010-07-01  1.666667  1.728000  1.351333  1.464000
# 2010-07-02 2010-07-02  1.533333  1.540000  1.247333  1.280000
# 2010-07-06 2010-07-06  1.333333  1.333333  1.055333  1.074000

# %%
df.tail()
# Out:
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2018-03-20 2018-03-20  20.991333  21.083332  20.584000  20.703333  20.703333
# 2018-03-21 2018-03-21  20.683332  21.496000  20.679333  21.101999  21.101999
# 2018-03-22 2018-03-22  20.926001  21.254667  20.545334  20.606667  20.606667
# 2018-03-23 2018-03-23  20.750000  20.750000  20.030001  20.102667  20.102667
# 2018-03-26 2018-03-26  20.489332  20.506001  19.424000  20.278667  20.278667
#
#                Volume
# Date
# 2018-03-20   71464500
# 2018-03-21   89376000
# 2018-03-22   74097000
# 2018-03-23   99823500
# 2018-03-26  125628000

# %%
df['2015':].iloc[:5,:5]
# Out:
#                  Date       Open       High        Low      Close
# Date
# 2015-01-02 2015-01-02  14.858000  14.883333  14.217333  14.620667
# 2015-01-05 2015-01-05  14.303333  14.433333  13.810667  14.006000
# 2015-01-06 2015-01-06  14.004000  14.280000  13.614000  14.085333
# 2015-01-07 2015-01-07  14.223333  14.318667  13.985333  14.063333
# 2015-01-08 2015-01-08  14.187333  14.253333  14.000667  14.041333

# %%
df['2015-03':].iloc[:5, :5]
# Out:
#                  Date       Open       High        Low      Close
# Date
# 2015-03-02 2015-03-02  13.513333  13.556000  13.055333  13.155333
# 2015-03-03 2015-03-03  13.120667  13.349333  13.021333  13.304000
# 2015-03-04 2015-03-04  13.283333  13.501333  13.147333  13.496000
# 2015-03-05 2015-03-05  13.523333  13.746000  13.343333  13.375333
# 2015-03-06 2015-03-06  13.280667  13.383333  12.810000  12.925333

# %%
df['ref_date'] = df['Date'] - df.index.min()

# %%
df
# Out:
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2010-06-29 2010-06-29   1.266667   1.666667   1.169333   1.592667   1.592667
# 2010-06-30 2010-06-30   1.719333   2.028000   1.553333   1.588667   1.588667
# 2010-07-01 2010-07-01   1.666667   1.728000   1.351333   1.464000   1.464000
# 2010-07-02 2010-07-02   1.533333   1.540000   1.247333   1.280000   1.280000
# 2010-07-06 2010-07-06   1.333333   1.333333   1.055333   1.074000   1.074000
# ...               ...        ...        ...        ...        ...        ...
# 2018-03-20 2018-03-20  20.991333  21.083332  20.584000  20.703333  20.703333
# 2018-03-21 2018-03-21  20.683332  21.496000  20.679333  21.101999  21.101999
# 2018-03-22 2018-03-22  20.926001  21.254667  20.545334  20.606667  20.606667
# 2018-03-23 2018-03-23  20.750000  20.750000  20.030001  20.102667  20.102667
# 2018-03-26 2018-03-26  20.489332  20.506001  19.424000  20.278667  20.278667
#
#                Volume  ref_date
# ...

# %%
df.index = df['ref_date']

# %%
df
# Out:
#                 Date       Open       High        Low      Close  Adj Close  \
# ref_date
# 0 days    2010-06-29   1.266667   1.666667   1.169333   1.592667   1.592667
# 1 days    2010-06-30   1.719333   2.028000   1.553333   1.588667   1.588667
# 2 days    2010-07-01   1.666667   1.728000   1.351333   1.464000   1.464000
# 3 days    2010-07-02   1.533333   1.540000   1.247333   1.280000   1.280000
# 7 days    2010-07-06   1.333333   1.333333   1.055333   1.074000   1.074000
# ...              ...        ...        ...        ...        ...        ...
# 2821 days 2018-03-20  20.991333  21.083332  20.584000  20.703333  20.703333
# 2822 days 2018-03-21  20.683332  21.496000  20.679333  21.101999  21.101999
# 2823 days 2018-03-22  20.926001  21.254667  20.545334  20.606667  20.606667
# 2824 days 2018-03-23  20.750000  20.750000  20.030001  20.102667  20.102667
# 2827 days 2018-03-26  20.489332  20.506001  19.424000  20.278667  20.278667
#
#               Volume  ref_date
# ref_date
# ...

# %%
df.iloc[:5, :5]
# Out:
#                Date      Open      High       Low     Close
# ref_date
# 0 days   2010-06-29  1.266667  1.666667  1.169333  1.592667
# 1 days   2010-06-30  1.719333  2.028000  1.553333  1.588667
# 2 days   2010-07-01  1.666667  1.728000  1.351333  1.464000
# 3 days   2010-07-02  1.533333  1.540000  1.247333  1.280000
# 7 days   2010-07-06  1.333333  1.333333  1.055333  1.074000

# %%
df['5 days' :].iloc[:5, :5]
# Out:
#                Date      Open      High       Low     Close
# ref_date
# 7 days   2010-07-06  1.333333  1.333333  1.055333  1.074000
# 8 days   2010-07-07  1.093333  1.108667  0.998667  1.053333
# 9 days   2010-07-08  1.076000  1.168000  1.038000  1.164000
# 10 days  2010-07-09  1.172000  1.193333  1.103333  1.160000
# 13 days  2010-07-12  1.196667  1.204667  1.133333  1.136667

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df.iloc[:5, :5]
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0

# %%
head_range = pd.date_range('2014-12-31', '2015-01-05')

# %%
head_range
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', freq='D')
