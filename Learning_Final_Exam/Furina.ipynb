# %%
for i in range(1, 1000):
    print("레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!")
# Out:
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!
# 레일라... 넌 천재야.. 할 수 있잖아! 상처받지 말고! 나아가!

# %%
# %pip install ebooklib
# Out:
# Collecting ebooklibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading EbookLib-0.18.tar.gz (115 kB)
#      ---------------------------------------- 0.0/115.5 kB ? eta -:--:--
#      -------------------------------------- 115.5/115.5 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml in c:\users\starl\anaconda3\lib\site-packages (from ebooklib) (4.9.2)
# Requirement already satisfied: six in c:\users\starl\anaconda3\lib\site-packages (from ebooklib) (1.16.0)
# Building wheels for collected packages: ebooklib
#   Building wheel for ebooklib (setup.py): started
#   Building wheel for ebooklib (setup.py): finished with status 'done'
#   Created wheel for ebooklib: filename=EbookLib-0.18-py3-none-any.whl size=38802 sha256=f240e35d3af9e15b98b00ffbbe7d3de65926ef748bc5135fb94829ba68458c3c
#   Stored in directory: c:\users\starl\appdata\local\pip\cache\wheels\65\2b\63\68307c736d5a2fafeebe9df3e5eccacfe892204ce1fd31a03c
# Successfully built ebooklib
# Installing collected packages: ebooklib
# Successfully installed ebooklib-0.18

# %%
from ebooklib import epub

# 새로운 EPUB 책을 생성합니다
book = epub.EpubBook()

# 메타데이터를 설정합니다
book.set_identifier('id12345612991nncikk')
book.set_title('Sample book')
book.set_language('en')

book.add_author('Author Layla-focalors')

# 텍스트 파일을 읽습니다
text = "레일라는 평범한 소녀였습니다. 그러나 어느 날, 그녀는 자신의 마을이 고대 마법에 의해 저주받았음을 알게 되었습니다. 마을 사람들은 모두 돌로 변해버렸고, 레일라만이 살아남았습니다. 그녀는 저주를 풀기 위해 위험천만한 여행을 떠나기로 결심했습니다. 그녀의 여행은 신비한 숲을 통과하면서 시작되었습니다. 숲은 이상한 생물들로 가득 차 있었고, 그 중 일부는 레일라를 돕기 위해 나타났습니다. 그들은 그녀에게 마법의 지팡이를 주었고, 이 지팡이는 그녀가 앞으로 직면할 모든 위험을 극복하는 데 도움이 되었습니다. 레일라는 또한 높은 산을 오르고, 깊은 강을 건너며, 끝없는 사막을 통과하면서 여러 시련을 겪었습니다. 그러나 그녀는 결코 포기하지 않았고, 그녀의 용기와 결단력은 그녀를 계속 전진하게 만들었습니다. 결국, 레일라는 마지막으로 도전해야 할 곳, 고대 마법사의 성을 찾아냈습니다. 그녀는 성 안으로 들어가서 마법사와 대결했고, 그녀의 지팡이와 용기 덕분에 그를 이겼습니다. 마법사가 쓰러지자, 그의 저주는 풀렸고, 마을 사람들은 다시 원래의 모습으로 돌아왔습니다. 레일라의 여행은 그녀를 평범한 소녀에서 진정한 영웅으로 바꾸었습니다. 그녀는 저주를 풀고 마을을 구했지만, 무엇보다도 그녀는 자신의 용기와 결단력을 발견했습니다. 그녀의 이야기는 모험과 용기, 그리고 우정에 대한 이야기였습니다. 그리고 이제, 그녀의 이야기는 우리 모두에게 영감을 주는 전설이 되었습니다."
# 책에 새로운 페이지를 추가합니다
c1 = epub.EpubHtml(title='Chapter 1', file_name='chap_01.xhtml', lang='en')
c1.content = '<h1>Chapter 1</h1><p>' + text + '</p>'

# 책에 페이지를 추가합니다
book.add_item(c1)

# 목차를 생성합니다
book.toc = (epub.Link('chap_01.xhtml', 'Chapter 1', '1'),)

# EPUB 파일을 작성합니다
epub.write_epub('testmodel22.epub', book, {})

# %% [markdown]
# 레일라는 평범한 소녀였습니다. 그러나 어느 날, 그녀는 자신의 마을이 고대 마법에 의해 저주받았음을 알게 되었습니다. 마을 사람들은 모두 돌로 변해버렸고, 레일라만이 살아남았습니다. 그녀는 저주를 풀기 위해 위험천만한 여행을 떠나기로 결심했습니다.
#
# 그녀의 여행은 신비한 숲을 통과하면서 시작되었습니다. 숲은 이상한 생물들로 가득 차 있었고, 그 중 일부는 레일라를 돕기 위해 나타났습니다. 그들은 그녀에게 마법의 지팡이를 주었고, 이 지팡이는 그녀가 앞으로 직면할 모든 위험을 극복하는 데 도움이 되었습니다.
#
# 레일라는 또한 높은 산을 오르고, 깊은 강을 건너며, 끝없는 사막을 통과하면서 여러 시련을 겪었습니다. 그러나 그녀는 결코 포기하지 않았고, 그녀의 용기와 결단력은 그녀를 계속 전진하게 만들었습니다.
#
# 결국, 레일라는 마지막으로 도전해야 할 곳, 고대 마법사의 성을 찾아냈습니다. 그녀는 성 안으로 들어가서 마법사와 대결했고, 그녀의 지팡이와 용기 덕분에 그를 이겼습니다. 마법사가 쓰러지자, 그의 저주는 풀렸고, 마을 사람들은 다시 원래의 모습으로 돌아왔습니다.
#
# 레일라의 여행은 그녀를 평범한 소녀에서 진정한 영웅으로 바꾸었습니다. 그녀는 저주를 풀고 마을을 구했지만, 무엇보다도 그녀는 자신의 용기와 결단력을 발견했습니다. 그녀의 이야기는 모험과 용기, 그리고 우정에 대한 이야기였습니다. 그리고 이제, 그녀의 이야기는 우리 모두에게 영감을 주는 전설이 되었습니다.

# %%
word = 'Layla'
sent = 'Layla is cute'

# %%
print(word[0])
print(sent[0])
# Out:
# L
# L

# %%
sent[0:5]
# Out:
# 'Layla'

# %%
sent[:]
# Out:
# 'Layla is cute'

# %%
sent[:len(sent)]
# Out:
# 'Layla is cute'

# %%
sent[-7:-3]
# Out:
# 'is c'

# %%
sent[-3:]
# Out:
# 'ute'

# %%
sent[:3]
# Out:
# 'Lay'

# %%
sent[0:3]
# Out:
# 'Lay'

# %%
sent[4:]
# Out:
# 'a is cute'

# %%
sent[:]
# Out:
# 'Layla is cute'

# %%
sent[::2]
# Out:
# 'Lyai ue'

# %%
a = 'Name : Layla'
b = 'StudentID : 20230000'
c = 'Hobby : Study'
d = 'comment : Cute'
" ".join([a, b, c, d])
# Out:
# 'Name : Layla StudentID : 20230000 Hobby : Study comment : Cute'

# %%
text = """Guard: What? Ridden en a horse?
Queen Raiden: Yes!
Guard: You're using coconuts!
Queen Raiden: What?
Guard: You're Got ... coconutes[s] and you;re banagin' em together
"""
str(text.splitlines()[::2])
# Out:
# '[\'Guard: What? Ridden en a horse?\', "Guard: You\'re using coconuts!", "Guard: You\'re Got ... coconutes[s] and you;re banagin\' em together"]'

# %%
str(text.splitlines()[::2]).replace('Guard', 'Yae Miko')
# Out:
# '[\'Yae Miko: What? Ridden en a horse?\', "Yae Miko: You\'re using coconuts!", "Yae Miko: You\'re Got ... coconutes[s] and you;re banagin\' em together"]'

# %%
'{} is cute!'.format('Layla')
# Out:
# 'Layla is cute!'

# %%
"""{0}은 매우매우 착하고 귀엽고 사랑스럽습니다.
이 사악한 {1}은 {0}를 괴롭히는 원인 중 하나입니다.""".format('레일라', '나히다')
# Out:
# '레일라은 매우매우 착하고 귀엽고 사랑스럽습니다.\n이 사악한 나히다은 레일라를 괴롭히는 원인 중 하나입니다.'

# %%
"나히다는 {age}살 이상이다.".format(age=500)
# Out:
# '나히다는 500살 이상이다.'

# %%
"나는! {:,}살 까지 살고 싶다!".format(999999999999)
# Out:
# '나는! 999,999,999,999살 까지 살고 싶다!'

# %%
'소스코드의 숫자는 {0:.3}개 이며, {0:.3%}이 값들을 가진다.'.format(7/68790)
# Out:
# '소스코드의 숫자는 0.000102개 이며, 0.010%이 값들을 가진다.'

# %%
"my user id code is {:06d}".format(12)
# Out:
# 'my user id code is 000012'

# %%
'my love number is %d' % 7
# Out:
# 'my love number is 7'

# %%
'%(name)s is very cute, but her sleep time is %(time).2f' % {'name':'Layla', 'time':1.1631212}
# Out:
# 'Layla is very cute, but her sleep time is 1.16'

# %%
name = '레일라'
month = 12
day = 19
f"{name}! {month}/{day} 생일 축하해!"
# Out:
# '레일라! 12/19 생일 축하해!'

# %%
import re
ax = re.match(pattern='\d{10}', string='1234567890')
ax
# Out:
# <re.Match object; span=(0, 10), match='1234567890'>

# %%
if(bool(ax)):
    print('match')
else:
    print('un match')
# Out:
# match

# %%
"match" if bool(ax) else "Unmatch"
# 3항 연산자
# Out:
# 'match'

# %%
ax.start()
# Out:
# 0

# %%
ax.end()
# Out:
# 10

# %%
ax.group()
# Out:
# '1234567890'

# %%
ax.span()
# Out:
# (0, 10)

# %%
re.match(pattern='\d{3}\s\d{4}\s\d{4}', string='123 4567 8901')
# Out:
# <re.Match object; span=(0, 13), match='123 4567 8901'>

# %%
re.match(pattern='\(\d{3}\)\s\d{3}\-\d{4}', string='(123) 456-7890')
# Out:
# <re.Match object; span=(0, 14), match='(123) 456-7890'>

# %%
re.match(pattern='\+\d{1}\s\d{3}\-\d{4}', string='+1 (123) 456-7890')

# %%
re.match(pattern='\+\d{1}\s\(\d{3}\)\s\-\d{4}', string='+1 (123) 456-7890')

# %%
re.match(pattern='\+\d\s\(\d{3}\)\s\d{3}\-\d{4}', string='+1 (123) 456-7890')
# Out:
# <re.Match object; span=(0, 17), match='+1 (123) 456-7890'>

# %%
re.match(pattern='\+\d{1,3}\s\(\d{3}\)\s\d{3}\-\d{4}', string='+1 (123) 456-7890')
# Out:
# <re.Match object; span=(0, 17), match='+1 (123) 456-7890'>

# %%
p = re.compile('\D{9}\:\d{4}')
p.match(string='localhost:8888')
# Out:
# <re.Match object; span=(0, 14), match='localhost:8888'>

# %%
p.groups
# Out:
# 0

# %%
p = re.compile('\D{9}\:\d{4}')
p.match(string='localhost:8888').group()
# Out:
# 'localhost:8888'

# %%
def my_exp(data):
    return data ** 2

# %%
def my_exp_c(data, n):
    return data ** n

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'a' : [10, 20, 30],
    'b' : [20, 30, 40]
})

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df['a'].apply(my_exp)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df['a'].transform(my_exp)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df['a'].agg(my_exp)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df ** 2
# Out:
#      a     b
# 0  100   400
# 1  400   900
# 2  900  1600

# %%
df['a'] ** 2
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df['a'].transform(my_exp_c, n=10)
# Out:
# 0        10000000000
# 1     10240000000000
# 2    590490000000000
# Name: a, dtype: int64

# %%
printme = lambda x : print(x)

# %%
df.agg(printme, axis=0)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# a    None
# b    None
# dtype: object

# %%
df.agg(printme, axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# a    20
# b    30
# Name: 1, dtype: int64
# a    30
# b    40
# Name: 2, dtype: int64
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def my_mean(data, tm):
    sum = 0
    for i in data:
        sum += i
    if(tm == 0):
        return sum / df.shape[0]
    else:
        return sum / df.shape[1]

# %%
df.agg(my_mean, tm=0)
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
df.agg(my_mean, tm = 1, axis = 1)
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
import seaborn as sns

# %%
getNAN = lambda x : pd.isnull(x).sum()

df.apply(getNAN)
# Out:
# a    0
# b    0
# dtype: int64

# %%
df = sns.load_dataset("titanic")
df.apply(getNAN)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
getNANP = lambda x : (pd.isnull(x).sum()) / len(x)
df.apply(getNANP)
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
def GetPRN(x):
    return (pd.isnull(x).sum()) / x.size
df.apply(GetPRN)
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
getNANP_2 = lambda x : ((pd.isnull(x).sum()) / len(x)) * 100
df.apply(getNANP_2)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
notNAN = lambda x : (1-(pd.isnull(x).sum() / len(x)))
df.apply(notNAN)
# Out:
# survived       1.000000
# pclass         1.000000
# sex            1.000000
# age            0.801347
# sibsp          1.000000
# parch          1.000000
# fare           1.000000
# embarked       0.997755
# class          1.000000
# who            1.000000
# adult_male     1.000000
# deck           0.227834
# embark_town    0.997755
# alive          1.000000
# alone          1.000000
# dtype: float64

# %%
nonNANP = lambda x : (1-(pd.isnull(x).sum() / len(x))) * 100
df.apply(nonNANP)
# Out:
# survived       100.000000
# pclass         100.000000
# sex            100.000000
# age             80.134680
# sibsp          100.000000
# parch          100.000000
# fare           100.000000
# embarked        99.775533
# class          100.000000
# who            100.000000
# adult_male     100.000000
# deck            22.783389
# embark_town     99.775533
# alive          100.000000
# alone          100.000000
# dtype: float64

# %%
df.apply(notNAN, axis = 1)
# Out:
# 0      0.933333
# 1      1.000000
# 2      0.933333
# 3      1.000000
# 4      0.933333
#          ...
# 886    0.933333
# 887    1.000000
# 888    0.866667
# 889    1.000000
# 890    0.933333
# Length: 891, dtype: float64

# %%
countNAN = lambda x : pd.isnull(x).sum()
df['missing'] = df.apply(countNAN, axis = 1)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  missing
# 0      man        True  NaN  Southampton    no  False        1
# 1    woman       False    C    Cherbourg   yes  False        0
# 2    woman       False  NaN  Southampton   yes   True        1
# 3    woman       False    C  Southampton   yes  False        0
# 4      man        True  NaN  Southampton    no   True        1
# ..     ...         ...  ...          ...   ...    ...      ...
# 886    man        True  NaN  Southampton    no   True        1
# 887  woman       False    B  Southampton   yes   True        0
# 888  woman       False  NaN  Southampton    no  False        2
# 889    man        True    C    Cherbourg   yes   True        0
# 890    man        True  NaN   Queenstown    no   True        1
#
# [891 rows x 16 columns]

# %%
df[df['missing'] >= 2].sample(100)
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 601         0       3    male  NaN      0      0   7.8958        S   Third
# 126         0       3    male  NaN      0      0   7.7500        Q   Third
# 454         0       3    male  NaN      0      0   8.0500        S   Third
# 653         1       3  female  NaN      0      0   7.8292        Q   Third
# 64          0       1    male  NaN      0      0  27.7208        C   First
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 497         0       3    male  NaN      0      0  15.1000        S   Third
# 639         0       3    male  NaN      1      0  16.1000        S   Third
# 674         0       2    male  NaN      0      0   0.0000        S  Second
# 611         0       3    male  NaN      0      0   7.0500        S   Third
# 354         0       3    male  NaN      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone  missing
# 601    man        True  NaN  Southampton    no   True        2
# 126    man        True  NaN   Queenstown    no   True        2
# 454    man        True  NaN  Southampton    no   True        2
# 653  woman       False  NaN   Queenstown   yes   True        2
# 64     man        True  NaN    Cherbourg    no   True        2
# ..     ...         ...  ...          ...   ...    ...      ...
# 497    man        True  NaN  Southampton    no   True        2
# 639    man        True  NaN  Southampton    no  False        2
# 674    man        True  NaN  Southampton    no   True        2
# 611    man        True  NaN  Southampton    no   True        2
# 354    man        True  NaN    Cherbourg    no   True        2
#
# [100 rows x 16 columns]

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df['lifeExp'].mean()
# Out:
# 59.474439366197174

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
y_1952 = df[df['year'] == 1952]['lifeExp'].mean()
y_1957 = df[df['year'] == 1957]['lifeExp'].mean()
y_1962 = df[df['year'] == 1962]['lifeExp'].mean()
y_2007 = df[df['year'] == 2007]['lifeExp'].mean()

# %%
df = pd.DataFrame({
    'year' : [1952, 1957, 1962, 2007],
    "" : [y_1952, y_1957, y_1962, y_2007]
})

# %%
df
# Out:
#    year
# 0  1952  49.057620
# 1  1957  51.507401
# 2  1962  53.609249
# 3  2007  67.007423

# %%
def getMean(data):
    sum = 0
    for i in data:
        sum += i
    return sum / len(data)

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')

# %%
df.groupby('year').agg(getMean)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\423667373.py:1: FutureWarning: ['country', 'continent'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('year').agg(getMean)
#         lifeExp           pop     gdpPercap
# year
# 1952  49.057620  1.695040e+07   3725.276046
# 1957  51.507401  1.876341e+07   4299.408345
# 1962  53.609249  2.042101e+07   4725.812342
# 1967  55.678290  2.265830e+07   5483.653047
# 1972  57.647386  2.518998e+07   6770.082815
# 1977  59.570157  2.767638e+07   7313.166421
# 1982  61.533197  3.020730e+07   7518.901673
# 1987  63.212613  3.303857e+07   7900.920218
# 1992  64.160338  3.599092e+07   8158.608521
# 1997  65.014676  3.883947e+07   9090.175363
# 2002  65.694923  4.145759e+07   9917.848365
# 2007  67.007423  4.402122e+07  11680.071820

# %%
df.mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# year         1.979500e+03
# lifeExp      5.947444e+01
# pop          2.960121e+07
# gdpPercap    7.215327e+03
# dtype: float64

# %%
df.groupby('year')['lifeExp'].agg(getMean)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
def getMean2(data, n):
    sum = 0
    for i in data:
        sum += i
    return sum / len(data) - n

df.groupby('year')['lifeExp'].agg(getMean2, n=df['lifeExp'].mean())
# Out:
# year
# 1952   -10.416820
# 1957    -7.967038
# 1962    -5.865190
# 1967    -3.796150
# 1972    -1.827053
# 1977     0.095718
# 1982     2.058758
# 1987     3.738173
# 1992     4.685899
# 1997     5.540237
# 2002     6.220483
# 2007     7.532983
# Name: lifeExp, dtype: float64

# %%
def getMean2(data, n):
    sum = 0
    for i in data:
        sum += i
    return (sum / len(data)) - n

df.groupby('year')['lifeExp'].agg(getMean2, n=df['lifeExp'].mean())
# Out:
# year
# 1952   -10.416820
# 1957    -7.967038
# 1962    -5.865190
# 1967    -3.796150
# 1972    -1.827053
# 1977     0.095718
# 1982     2.058758
# 1987     3.738173
# 1992     4.685899
# 1997     5.540237
# 2002     6.220483
# 2007     7.532983
# Name: lifeExp, dtype: float64

# %%
import numpy as np

# %%
df.groupby('year')['lifeExp'].agg([np.count_nonzero, np.mean, np.std])
# Out:
#       count_nonzero       mean        std
# year
# 1952            142  49.057620  12.225956
# 1957            142  51.507401  12.231286
# 1962            142  53.609249  12.097245
# 1967            142  55.678290  11.718858
# 1972            142  57.647386  11.381953
# 1977            142  59.570157  11.227229
# 1982            142  61.533197  10.770618
# 1987            142  63.212613  10.556285
# 1992            142  64.160338  11.227380
# 1997            142  65.014676  11.559439
# 2002            142  65.694923  12.279823
# 2007            142  67.007423  12.073021

# %%
df.groupby('year').agg({'lifeExp':'mean', 'pop':'median', 'gdpPercap':'median'})
# Out:
#         lifeExp         pop    gdpPercap
# year
# 1952  49.057620   3943953.0  1968.528344
# 1957  51.507401   4282942.0  2173.220291
# 1962  53.609249   4686039.5  2335.439533
# 1967  55.678290   5170175.5  2678.334740
# 1972  57.647386   5877996.5  3339.129407
# 1977  59.570157   6404036.5  3798.609244
# 1982  61.533197   7007320.0  4216.228428
# 1987  63.212613   7774861.5  4280.300366
# 1992  64.160338   8688686.5  4386.085502
# 1997  65.014676   9735063.5  4781.825478
# 2002  65.694923  10372918.5  5319.804524
# 2007  67.007423  10517531.0  6124.371108

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
z_score = lambda x : (x - x.mean()) / x.std()

df.transform(z_score)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\2702956797.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z_score = lambda x : (x - x.mean()) / x.std()
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\2702956797.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   z_score = lambda x : (x - x.mean()) / x.std()
#      continent country  gdpPercap   lifeExp       pop      year
# 0          NaN     NaN  -0.652895 -2.374637 -0.199475 -1.592787
# 1          NaN     NaN  -0.648694 -2.256112 -0.191792 -1.303190
# 2          NaN     NaN  -0.645423 -2.127213 -0.182126 -1.013592
# 3          NaN     NaN  -0.647138 -1.970599 -0.170155 -0.723994
# 4          NaN     NaN  -0.656898 -1.810501 -0.155634 -0.434397
# ...        ...     ...        ...       ...       ...       ...
# 1699       NaN     NaN  -0.660330  0.222694 -0.192023  0.434397
# 1700       NaN     NaN  -0.661622  0.069873 -0.178007  0.723994
# 1701       NaN     NaN  -0.651576 -0.980517 -0.171408  1.013592
# 1702       NaN     NaN  -0.663791 -1.508499 -0.166494  1.303190
# 1703       NaN     NaN  -0.684316 -1.237695 -0.162871  1.592787
#
# [1704 rows x 6 columns]

# %%
def getZ_score(z):
    return (z - z.mean()) / z.std()

df.transform(getZ_score)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\136522291.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return (z - z.mean()) / z.std()
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\136522291.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return (z - z.mean()) / z.std()
#      continent country  gdpPercap   lifeExp       pop      year
# 0          NaN     NaN  -0.652895 -2.374637 -0.199475 -1.592787
# 1          NaN     NaN  -0.648694 -2.256112 -0.191792 -1.303190
# 2          NaN     NaN  -0.645423 -2.127213 -0.182126 -1.013592
# 3          NaN     NaN  -0.647138 -1.970599 -0.170155 -0.723994
# 4          NaN     NaN  -0.656898 -1.810501 -0.155634 -0.434397
# ...        ...     ...        ...       ...       ...       ...
# 1699       NaN     NaN  -0.660330  0.222694 -0.192023  0.434397
# 1700       NaN     NaN  -0.661622  0.069873 -0.178007  0.723994
# 1701       NaN     NaN  -0.651576 -0.980517 -0.171408  1.013592
# 1702       NaN     NaN  -0.663791 -1.508499 -0.166494  1.303190
# 1703       NaN     NaN  -0.684316 -1.237695 -0.162871  1.592787
#
# [1704 rows x 6 columns]

# %%
df.groupby('year')['lifeExp'].transform(z_score)
# Out:
# 0      -1.656854
# 1      -1.731249
# 2      -1.786543
# 3      -1.848157
# 4      -1.894173
#           ...
# 1699   -0.081621
# 1700   -0.336974
# 1701   -1.574962
# 1702   -2.093346
# 1703   -1.948180
# Name: lifeExp, Length: 1704, dtype: float64

# %%
import random

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = df.sample(10)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 41        17.46  2.54    Male     No   Sun  Dinner     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 99        12.46  1.50    Male     No   Fri  Dinner     2

# %%
df.loc[np.random.permutation(df.index)[:4], 'total_bill'] = np.NAN

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 41          NaN  2.54    Male     No   Sun  Dinner     2
# 223         NaN  3.00  Female     No   Fri   Lunch     3
# 234         NaN  3.00    Male    Yes   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 130       19.08  1.50    Male     No  Thur   Lunch     2
# 73          NaN  5.00  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 99        12.46  1.50    Male     No   Fri  Dinner     2

# %%
df.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Male             4    6       6    6     6     6
# Female           2    4       4    4     4     4

# %%
def sexc(data):
    data.fillna(data.mean())

df['meanofsex'] = df.groupby('sex')['total_bill'].transform(sexc)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\179150874.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['meanofsex'] = df.groupby('sex')['total_bill'].transform(sexc)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  meanofsex
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2        NaN
# 41          NaN  2.54    Male     No   Sun  Dinner     2        NaN
# 223         NaN  3.00  Female     No   Fri   Lunch     3        NaN
# 234         NaN  3.00    Male    Yes   Sat  Dinner     2        NaN
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2        NaN
# 162       16.21  2.00  Female     No   Sun  Dinner     3        NaN
# 130       19.08  1.50    Male     No  Thur   Lunch     2        NaN
# 73          NaN  5.00  Female    Yes   Sat  Dinner     2        NaN
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5        NaN
# 99        12.46  1.50    Male     No   Fri  Dinner     2        NaN

# %%
def fill_na_mean(x):
    return x.fillna(x.mean())

df['mean_sex'] = df.groupby('sex')['total_bill'].transform(fill_na_mean)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  meanofsex  mean_sex
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2        NaN    28.970
# 41          NaN  2.54    Male     No   Sun  Dinner     2        NaN    22.165
# 223         NaN  3.00  Female     No   Fri   Lunch     3        NaN    19.165
# 234         NaN  3.00    Male    Yes   Sat  Dinner     2        NaN    22.165
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2        NaN    22.120
# 162       16.21  2.00  Female     No   Sun  Dinner     3        NaN    16.210
# 130       19.08  1.50    Male     No  Thur   Lunch     2        NaN    19.080
# 73          NaN  5.00  Female    Yes   Sat  Dinner     2        NaN    19.165
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5        NaN    28.150
# 99        12.46  1.50    Male     No   Fri  Dinner     2        NaN    12.460

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
def sexc(data):
    return data.fillna(data.mean())

df['meanofsex'] = df.groupby('sex')['total_bill'].transform(sexc)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  meanofsex  mean_sex
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2     28.970    28.970
# 41          NaN  2.54    Male     No   Sun  Dinner     2     22.165    22.165
# 223         NaN  3.00  Female     No   Fri   Lunch     3     19.165    19.165
# 234         NaN  3.00    Male    Yes   Sat  Dinner     2     22.165    22.165
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2     22.120    22.120
# 162       16.21  2.00  Female     No   Sun  Dinner     3     16.210    16.210
# 130       19.08  1.50    Male     No  Thur   Lunch     2     19.080    19.080
# 73          NaN  5.00  Female    Yes   Sat  Dinner     2     19.165    19.165
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5     28.150    28.150
# 99        12.46  1.50    Male     No   Fri  Dinner     2     12.460    12.460

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
df['size'][df.filter(df['size'].value_counts() >= 30)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df['size'][df.filter(df['size'].value_counts() >= 30)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     key = np.asarray(key, dtype=bool)
#    1005     return self._get_values(key)
# -> 1007 return self._get_with(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1017, in Series._get_with(self, key)
#    1015     return self._slice(slobj)
#    1016 elif isinstance(key, ABCDataFrame):
# -> 1017     raise TypeError(
#    1018         "Indexing a Series with DataFrame is not "
#    1019         "supported, use the appropriate DataFrame column"
#    1020     )
#    1021 elif isinstance(key, tuple):
#    1022     return self._get_values_tuple(key)
#
# TypeError: Indexing a Series with DataFrame is not supported, use the appropriate DataFrame column

# %%
tips_filtered = df.groupby('size').filter(lambda x : x['size'].value_counts() >= 30)

# %%
tips_filtered['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# Name: size, dtype: int64

# %%
df = sns.load_dataset("tips").sample(10, random_state=42)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
df.groupby('sex').groups
# Out:
# {'Male': [24, 6, 153, 211, 176, 192, 9], 'Female': [198, 124, 101]}

# %%
grouped = df.groupby('sex')
grouped

# %%
grouped.mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\2755795945.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#         total_bill       tip      size
# sex
# Male         20.02  2.875714  2.571429
# Female       13.62  2.506667  2.000000

# %%
grouped.get_group('Female')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2

# %%
for i in grouped:
    print(i)
# Out:
# ('Male',      total_bill   tip   sex smoker   day    time  size
# 24        19.82  3.18  Male     No   Sat  Dinner     2
# 6          8.77  2.00  Male     No   Sun  Dinner     2
# 153       24.55  2.00  Male     No   Sun  Dinner     4
# 211       25.89  5.16  Male    Yes   Sat  Dinner     4
# 176       17.89  2.00  Male    Yes   Sun  Dinner     2
# 192       28.44  2.56  Male    Yes  Thur   Lunch     2
# 9         14.78  3.23  Male     No   Sun  Dinner     2)
# ('Female',      total_bill   tip     sex smoker   day    time  size
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 124       12.48  2.52  Female     No  Thur   Lunch     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2)

# %%
grouped.

# %%
for i in grouped:
    print(f"type : {type(i)}")
    print(f'length : {len(i)}')
    print(f"name : {i[0]}")
    print('----------------------')
# Out:
# type : <class 'tuple'>
# length : 2
# name : Male
# ----------------------
# type : <class 'tuple'>
# length : 2
# name : Female
# ----------------------

# %%
grouped

# %%
grouped.reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 grouped.reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'reset_index'

# %%
df.groupby(['sex', 'time']).mean().reset_index()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\2848853033.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex', 'time']).mean().reset_index()
#       sex    time  total_bill       tip      size
# 0    Male   Lunch   28.440000  2.560000  2.000000
# 1    Male  Dinner   18.616667  2.928333  2.666667
# 2  Female   Lunch   12.740000  2.260000  2.000000
# 3  Female  Dinner   15.380000  3.000000  2.000000

# %%
df.groupby(['sex','time'], as_index=False).mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\54886949.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['sex','time'], as_index=False).mean()
#       sex    time  total_bill       tip      size
# 0    Male   Lunch   28.440000  2.560000  2.000000
# 1    Male  Dinner   18.616667  2.928333  2.666667
# 2  Female   Lunch   12.740000  2.260000  2.000000
# 3  Female  Dinner   15.380000  3.000000  2.000000

# %%
import datetime

# %%
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2023, 12, 8, 15, 32, 19, 395449)

# %%
print(now)
# Out:
# 2023-12-08 15:32:19.395449

# %%
print(datetime.datetime.today())
# Out:
# 2023-12-08 15:33:06.065244

# %%
print(datetime.datetime(1970, 1, 1))
print(datetime.datetime(2023, 12, 19, 6, 14))
# Out:
# 1970-01-01 00:00:00
# 2023-12-19 06:14:00

# %%
a = (datetime.datetime(1970, 1, 1))
b = (datetime.datetime(2023, 12, 19, 6, 14))
print(b - a)
# Out:
# 19710 days, 6:14:00

# %%
print(a - b)
# Out:
# -19711 days, 17:46:00

# %%
print(type(a - b))
# Out:
# <class 'datetime.timedelta'>

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
df = pd.read_csv('../data/country_timeseries.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
df = pd.DataFrame({
    'date' : ['01/01/15', '02/01/15', '03/01/15']
})

# %%
df
# Out:
#        date
# 0  01/01/15
# 1  02/01/15
# 2  03/01/15

# %%
df['parse_date'] = pd.to_datetime(df['date'], format='%d/%m/%y')
df['parse_date2'] = pd.to_datetime(df['date'], format='%m/%d/%y')
df['parse_date3'] = pd.to_datetime(df['date'], format='%y/%m/%d')

# %%
df
# Out:
#        date parse_date parse_date2 parse_date3
# 0  01/01/15 2015-01-01  2015-01-01  2001-01-15
# 1  02/01/15 2015-01-02  2015-02-01  2002-01-15
# 2  03/01/15 2015-01-03  2015-03-01  2003-01-15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3 non-null      object
#  1   parse_date   3 non-null      datetime64[ns]
#  2   parse_date2  3 non-null      datetime64[ns]
#  3   parse_date3  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](3), object(1)
# memory usage: 228.0+ bytes

# %%
now = datetime.datetime.now()
print(now.strftime('%Y-%m-%d'))
# Out:
# 2023-12-08

# %%
print(now.strftime('%H:%M:%S'))
# Out:
# 15:39:01

# %%
print(now.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2023-12-08 15:39:01

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
s = pd.Series(['2018-05-16', '2018-05-17', '2018-05-18'])

# %%
s
# Out:
# 0    2018-05-16
# 1    2018-05-17
# 2    2018-05-18
# dtype: object

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
sx = pd.to_datetime(s, format='%Y-%m-%d')

# %%
sx.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.0 bytes

# %%
sx
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[ns]

# %%
sx.dt.year
# Out:
# 0    2018
# 1    2018
# 2    2018
# dtype: int64

# %%
sx.dt.month
# Out:
# 0    5
# 1    5
# 2    5
# dtype: int64

# %%
sx.dt.day
# Out:
# 0    16
# 1    17
# 2    18
# dtype: int64

# %%
sx[0].year
# Out:
# 2018

# %%
sx[0].month
# Out:
# 5

# %%
sx[0].day
# Out:
# 16

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
df['year'], df['month'], df['day'] = (df['Date'].dt.year, df['Date'].dt.month, df['Date'].dt.day)

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  ...  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           NaN  ...             NaN              2977.0             NaN
# 1           NaN  ...             NaN              2943.0             NaN
# 2           NaN  ...          3496.0              2915.0             NaN
# 3           NaN  ...          3496.0                 NaN             NaN
# 4           NaN  ...          3471.0              2827.0             NaN
# ..          ...  ...             ...                 ...             ...
# 117         NaN  ...             6.0                 5.0             NaN
# 118         NaN  ...             NaN                 NaN             NaN
# 119         NaN  ...             NaN                 NaN             NaN
# 120         NaN  ...             NaN                 NaN             NaN
# 121         NaN  ...             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali  year  \
# 0               NaN                  NaN           NaN          NaN  2015
# 1               NaN                  NaN           NaN          NaN  2015
# 2               NaN                  NaN           NaN          NaN  2015
# 3               NaN                  NaN           NaN          NaN  2015
# 4               NaN                  NaN           NaN          NaN  2014
# ..              ...                  ...           ...          ...   ...
# 117             NaN                  NaN           NaN          NaN  2014
# 118             NaN                  NaN           NaN          NaN  2014
# 119             NaN                  NaN           NaN          NaN  2014
# 120             NaN                  NaN           NaN          NaN  2014
# 121             NaN                  NaN           NaN          NaN  2014
#
#      month  day
# 0        1    5
# 1        1    4
# 2        1    3
# 3        1    2
# 4       12   31
# ..     ...  ...
# 117      3   27
# 118      3   26
# 119      3   25
# 120      3   24
# 121      3   22
#
# [122 rows x 21 columns]

# %%
df[['Date', 'year', 'month', 'day']]
# Out:
#           Date  year  month  day
# 0   2015-01-05  2015      1    5
# 1   2015-01-04  2015      1    4
# 2   2015-01-03  2015      1    3
# 3   2015-01-02  2015      1    2
# 4   2014-12-31  2014     12   31
# ..         ...   ...    ...  ...
# 117 2014-03-27  2014      3   27
# 118 2014-03-26  2014      3   26
# 119 2014-03-25  2014      3   25
# 120 2014-03-24  2014      3   24
# 121 2014-03-22  2014      3   22
#
# [122 rows x 4 columns]

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  ...  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           NaN  ...             NaN              2977.0             NaN
# 1           NaN  ...             NaN              2943.0             NaN
# 2           NaN  ...          3496.0              2915.0             NaN
# 3           NaN  ...          3496.0                 NaN             NaN
# 4           NaN  ...          3471.0              2827.0             NaN
# ..          ...  ...             ...                 ...             ...
# 117         NaN  ...             6.0                 5.0             NaN
# 118         NaN  ...             NaN                 NaN             NaN
# 119         NaN  ...             NaN                 NaN             NaN
# 120         NaN  ...             NaN                 NaN             NaN
# 121         NaN  ...             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali  year  \
# 0               NaN                  NaN           NaN          NaN  2015
# 1               NaN                  NaN           NaN          NaN  2015
# 2               NaN                  NaN           NaN          NaN  2015
# 3               NaN                  NaN           NaN          NaN  2015
# 4               NaN                  NaN           NaN          NaN  2014
# ..              ...                  ...           ...          ...   ...
# 117             NaN                  NaN           NaN          NaN  2014
# 118             NaN                  NaN           NaN          NaN  2014
# 119             NaN                  NaN           NaN          NaN  2014
# 120             NaN                  NaN           NaN          NaN  2014
# 121             NaN                  NaN           NaN          NaN  2014
#
#      month  day
# 0        1    5
# 1        1    4
# 2        1    3
# 3        1    2
# 4       12   31
# ..     ...  ...
# 117      3   27
# 118      3   26
# 119      3   25
# 120      3   24
# 121      3   22
#
# [122 rows x 21 columns]

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
df.index = df['Date']
df.index.min()
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
df['outbreak_d'] = df['Date'] - df.index.min()

# %%
df['outbreak_d2'] = df['Date'] - df['Date'].min()

# %%
df[['Date','outbreak_d', 'outbreak_d2']]
# Out:
#                  Date outbreak_d outbreak_d2
# Date
# 2015-01-05 2015-01-05   289 days    289 days
# 2015-01-04 2015-01-04   288 days    288 days
# 2015-01-03 2015-01-03   287 days    287 days
# 2015-01-02 2015-01-02   286 days    286 days
# 2014-12-31 2014-12-31   284 days    284 days
# ...               ...        ...         ...
# 2014-03-27 2014-03-27     5 days      5 days
# 2014-03-26 2014-03-26     4 days      4 days
# 2014-03-25 2014-03-25     3 days      3 days
# 2014-03-24 2014-03-24     2 days      2 days
# 2014-03-22 2014-03-22     0 days      0 days
#
# [122 rows x 3 columns]

# %%
df = pd.read_csv('../data/banklist.csv', parse_dates=['Closing Date'])

# %%
df
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# 0    30570                   Royal Savings Bank   2017-12-15    20-Dec-17
# 1    17719                          Conway Bank   2017-10-13    20-Oct-17
# 2     1802            United Fidelity Bank, fsb   2017-05-26    26-Jul-17
# 3    30003  First-Citizens Bank & Trust Company   2017-05-05    26-Jul-17
# 4    58302                         Whitney Bank   2017-04-28     5-Dec-17
# ..     ...                                  ...          ...          ...
# 550  32646                Superior Federal, FSB   2001-07-27    19-Aug-14
# 551   6629                    North Valley Bank   2001-05-03    18-Nov-02
# 552  34264  Southern New Hampshire Bank & Trust   2001-02-02    18-Feb-03
# 553   3815              Banterra Bank of Marion   2000-12-14    17-Mar-05
# 554  21029                   Bank of the Orient   2000-10-13    17-Mar-05
#
# [555 rows x 7 columns]

# %%
df['closing_year'], df['closing_quarter'] = (df['Closing Date'].dt.year, df['Closing Date'].dt.quarter)

# %%
df[['Closing Date', 'closing_year', 'closing_quarter']]
# Out:
#     Closing Date  closing_year  closing_quarter
# 0     2017-12-15          2017                4
# 1     2017-10-13          2017                4
# 2     2017-05-26          2017                2
# 3     2017-05-05          2017                2
# 4     2017-04-28          2017                2
# ..           ...           ...              ...
# 550   2001-07-27          2001                3
# 551   2001-05-03          2001                2
# 552   2001-02-02          2001                1
# 553   2000-12-14          2000                4
# 554   2000-10-13          2000                4
#
# [555 rows x 3 columns]

# %%
df['closing_year'].value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: closing_year, dtype: int64

# %%
print(df['closing_year'].value_counts())
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: closing_year, dtype: int64

# %%
df.groupby('closing_year').size()
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %%
df.groupby(['closing_year', 'closing_quarter']).size()
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
#               4                   2
# dtype: int64

# %%
df.groupby(['closing_year', 'closing_quarter']).size().plot()
# Out:
# <Axes: xlabel='closing_year,closing_quarter'>

# %%
sns.lineplot(data=df.groupby(['closing_year', 'closing_quarter']).size())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 sns.lineplot(data=df.groupby(['closing_year', 'closing_quarter']).size())
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
#     625 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     626 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:365, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     351 def __init__(
#     352     self, *,
#     353     data=None, variables={},
#    (...)
#     359     # the kind of plot to draw, but for the time being we need to set
#     360     # this information so the SizeMapping can use it
#     361     self._default_size_range = (
#     362         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     363     )
# --> 365     super().__init__(data=data, variables=variables)
#     367     self.estimator = estimator
#     368     self.errorbar = errorbar
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:696, in VectorPlotter.assign_variables(self, data, variables)
#     694 if x is None and y is None:
#     695     self.input_format = "wide"
# --> 696     plot_data, variables = self._assign_variables_wideform(
#     697         data, **variables,
#     698     )
#     699 else:
#     700     self.input_format = "long"
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:786, in VectorPlotter._assign_variables_wideform(self, data, **kwargs)
#     783             plot_data[var] = getattr(flat_data, attr[1:])
#     784             variables[var] = names[self.flat_structure[var]]
# --> 786     plot_data = pd.DataFrame(plot_data)
#     788 else:
#     789
#     790     # Otherwise assume we have some collection of vectors.
#    (...)
#     793     # not in the rows, of the intermediate wide DataFrame.
#     794     # One way to accomplish this is to convert to a dict of Series.
#     795     if isinstance(data, Sequence):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:482, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     480     columns = Index(keys)
#     481     arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
# --> 482     arrays = [arr if not isinstance(arr, Index) else arr._data for arr in arrays]
#     484 if copy:
#     485     if typ == "block":
#     486         # We only need to copy arrays that will not get consolidated, i.e.
#     487         #  only EA arrays
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:482, in <listcomp>(.0)
#     480     columns = Index(keys)
#     481     arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
# --> 482     arrays = [arr if not isinstance(arr, Index) else arr._data for arr in arrays]
#     484 if copy:
#     485     if typ == "block":
#     486         # We only need to copy arrays that will not get consolidated, i.e.
#     487         #  only EA arrays
#
# AttributeError: 'MultiIndex' object has no attribute '_data'

# %%
df.groupby(['closing_year','closing_quarter']).size()
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
#               4                   2
# dtype: int64

# %%
print(df.groupby(['closing_year','closing_quarter']).size())
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
#               4                   2
# dtype: int64

# %%
df.groupby(['closing_year','closing_quarter']).size().plot()
# Out:
# <Axes: xlabel='closing_year,closing_quarter'>

# %%
df.groupby(['closing_year','closing_quarter']).size().plot(color='pink')
# Out:
# <Axes: xlabel='closing_year,closing_quarter'>

# %%
df = pd.read_csv('../data/tesla_stock.csv', parse_dates=[0])

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3373 2023-11-21  235.039993  243.619995  233.339996  241.199997  241.199997
# 3374 2023-11-22  242.039993  244.009995  231.399994  234.210007  234.210007
# 3375 2023-11-24  233.750000  238.750000  232.330002  235.449997  235.449997
# 3376 2023-11-27  236.889999  238.330002  232.100006  236.080002  236.080002
# 3377 2023-11-28  236.679993  247.000000  234.009995  246.720001  246.720001
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...         ...
# 3373  122288000
# 3374  117950600
# 3375   65125200
# 3376  112031800
# 3377  147004708
#
# [3378 rows x 7 columns]

# %%
df[(df['Date'].dt.year == 2010) & (df['Date'].dt.month == 6)]
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500

# %%
df.index = df['Date']

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...               ...         ...         ...         ...         ...
# 2023-11-21 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 2023-11-22 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 2023-11-24 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 2023-11-27 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#              Adj Close     Volume
# Date
# 2010-06-29    1.592667  281494500
# 2010-06-30    1.588667  257806500
# 2010-07-01    1.464000  123282000
# 2010-07-02    1.280000   77097000
# 2010-07-06    1.074000  103003500
# ...                ...        ...
# 2023-11-21  241.199997  122288000
# 2023-11-22  234.210007  117950600
# 2023-11-24  235.449997   65125200
# 2023-11-27  236.080002  112031800
# 2023-11-28  246.720001  147004708
#
# [3378 rows x 7 columns]

# %%
df[2015]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2015
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[273], line 1
# ----> 1 df[2015]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 2015

# %%
df['2015']
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\3483409441.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2015']
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2015-01-02 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667
# 2015-01-05 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000
# 2015-01-06 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333
# 2015-01-07 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333
# 2015-01-08 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333
# ...               ...        ...        ...        ...        ...        ...
# 2015-12-24 2015-12-24  15.370667  15.458667  15.218667  15.371333  15.371333
# 2015-12-28 2015-12-28  15.432667  15.465333  15.036000  15.263333  15.263333
# 2015-12-29 2015-12-29  15.337333  15.848000  15.303333  15.812667  15.812667
# 2015-12-30 2015-12-30  15.773333  16.242001  15.711333  15.872667  15.872667
# 2015-12-31 2015-12-31  15.900667  16.230000  15.891333  16.000668  16.000668
#
#               Volume
# Date
# 2015-01-02  71466000
# 2015-01-05  80527500
# 2015-01-06  93928500
# 2015-01-07  44526000
# 2015-01-08  51637500
# ...              ...
# 2015-12-24  10620000
# 2015-12-28  28519500
# 2015-12-29  36094500
# 2015-12-30  55468500
# 2015-12-31  40725000
#
# [252 rows x 7 columns]

# %%
df['2015'].head(5)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\1608812681.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2015'].head(5)
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2015-01-02 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667
# 2015-01-05 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000
# 2015-01-06 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333
# 2015-01-07 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333
# 2015-01-08 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333
#
#               Volume
# Date
# 2015-01-02  71466000
# 2015-01-05  80527500
# 2015-01-06  93928500
# 2015-01-07  44526000
# 2015-01-08  51637500

# %%
df['2017-3']
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\2227395474.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2017-3']
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2017-03-01 2017-03-01  16.945333  16.990000  16.607332  16.667999  16.667999
# 2017-03-02 2017-03-02  16.647333  16.885332  16.551332  16.698668  16.698668
# 2017-03-03 2017-03-03  16.716000  16.793333  16.600000  16.771334  16.771334
# 2017-03-06 2017-03-06  16.527332  16.780001  16.500668  16.747334  16.747334
# 2017-03-07 2017-03-07  16.794666  16.926001  16.554667  16.572666  16.572666
# 2017-03-08 2017-03-08  16.466667  16.671333  16.354668  16.458000  16.458000
# 2017-03-09 2017-03-09  16.508667  16.577333  16.200001  16.326668  16.326668
# 2017-03-10 2017-03-10  16.414000  16.433332  16.200001  16.246000  16.246000
# 2017-03-13 2017-03-13  16.321333  16.456667  16.185333  16.411333  16.411333
# 2017-03-14 2017-03-14  16.407333  17.208000  16.401333  17.200001  17.200001
# 2017-03-15 2017-03-15  17.133333  17.400000  16.951332  17.048668  17.048668
# 2017-03-16 2017-03-16  17.493334  17.716667  17.270666  17.469999  17.469999
# 2017-03-17 2017-03-17  17.600000  17.688667  17.413334  17.433332  17.433332
# 2017-03-20 2017-03-20  17.373333  17.636667  17.254667  17.461332  17.461332
# 2017-03-21 2017-03-21  17.521999  17.653334  16.682667  16.712000  16.712000
# 2017-03-22 2017-03-22  16.770666  17.004667  16.700666  17.000668  17.000668
# 2017-03-23 2017-03-23  17.025999  17.177999  16.886667  16.985332  16.985332
# 2017-03-24 2017-03-24  17.046667  17.592667  17.000668  17.544001  17.544001
# 2017-03-27 2017-03-27  17.373333  18.038000  17.316668  18.014668  18.014668
# 2017-03-28 2017-03-28  18.468000  18.712000  18.333332  18.496668  18.496668
# 2017-03-29 2017-03-29  18.556000  18.639999  18.369333  18.492001  18.492001
# 2017-03-30 2017-03-30  18.535999  18.799999  18.480667  18.528000  18.528000
# 2017-03-31 2017-03-31  18.582001  18.645332  18.421333  18.553333  18.553333
#
#                Volume
# Date
# 2017-03-01   72142500
# 2017-03-02   50277000
# 2017-03-03   43791000
# 2017-03-06   50332500
# 2017-03-07   51892500
# 2017-03-08   55878000
# 2017-03-09   58189500
# 2017-03-10   45994500
# 2017-03-13   45339000
# 2017-03-14  113976000
# 2017-03-15   79962000
# 2017-03-16  106983000
# 2017-03-17   97462500
# 2017-03-20   54214500
# 2017-03-21  103629000
# 2017-03-22   60889500
# 2017-03-23   49803000
# 2017-03-24   84709500
# 2017-03-27   93462000
# 2017-03-28  119814000
# 2017-03-29   55143000
# 2017-03-30   62226000
# 2017-03-31   49419000

# %%
df['ref_date'] = df['Date'] - df.index.min()

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...               ...         ...         ...         ...         ...
# 2023-11-21 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 2023-11-22 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 2023-11-24 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 2023-11-27 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#              Adj Close     Volume  ref_date
# Date
# 2010-06-29    1.592667  281494500    0 days
# 2010-06-30    1.588667  257806500    1 days
# 2010-07-01    1.464000  123282000    2 days
# 2010-07-02    1.280000   77097000    3 days
# 2010-07-06    1.074000  103003500    7 days
# ...                ...        ...       ...
# 2023-11-21  241.199997  122288000 4893 days
# 2023-11-22  234.210007  117950600 4894 days
# 2023-11-24  235.449997   65125200 4896 days
# 2023-11-27  236.080002  112031800 4899 days
# 2023-11-28  246.720001  147004708 4900 days
#
# [3378 rows x 8 columns]

# %%
dtn = pd.date_range(df.index.min(), df.index.max())
dtn
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-03', '2010-07-04', '2010-07-05', '2010-07-06',
#                '2010-07-07', '2010-07-08',
#                ...
#                '2023-11-19', '2023-11-20', '2023-11-21', '2023-11-22',
#                '2023-11-23', '2023-11-24', '2023-11-25', '2023-11-26',
#                '2023-11-27', '2023-11-28'],
#               dtype='datetime64[ns]', length=4901, freq='D')

# %%
df = df.reindex(dtn)

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# 2010-06-29 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-03        NaT         NaN         NaN         NaN         NaN
# ...               ...         ...         ...         ...         ...
# 2023-11-24 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 2023-11-25        NaT         NaN         NaN         NaN         NaN
# 2023-11-26        NaT         NaN         NaN         NaN         NaN
# 2023-11-27 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#              Adj Close       Volume  ref_date
# 2010-06-29    1.592667  281494500.0    0 days
# 2010-06-30    1.588667  257806500.0    1 days
# 2010-07-01    1.464000  123282000.0    2 days
# 2010-07-02    1.280000   77097000.0    3 days
# 2010-07-03         NaN          NaN       NaT
# ...                ...          ...       ...
# 2023-11-24  235.449997   65125200.0 4896 days
# 2023-11-25         NaN          NaN       NaT
# 2023-11-26         NaN          NaN       NaT
# 2023-11-27  236.080002  112031800.0 4899 days
# 2023-11-28  246.720001  147004708.0 4900 days
#
# [4901 rows x 8 columns]

# %%
df.index = df.ref_date

# %%
df
# Out:
#                 Date        Open        High         Low       Close  \
# ref_date
# 0 days    2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1 days    2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2 days    2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3 days    2010-07-02    1.533333    1.540000    1.247333    1.280000
# NaT              NaT         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# 4896 days 2023-11-24  233.750000  238.750000  232.330002  235.449997
# NaT              NaT         NaN         NaN         NaN         NaN
# NaT              NaT         NaN         NaN         NaN         NaN
# 4899 days 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 4900 days 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#             Adj Close       Volume  ref_date
# ref_date
# 0 days       1.592667  281494500.0    0 days
# 1 days       1.588667  257806500.0    1 days
# 2 days       1.464000  123282000.0    2 days
# 3 days       1.280000   77097000.0    3 days
# NaT               NaN          NaN       NaT
# ...               ...          ...       ...
# 4896 days  235.449997   65125200.0 4896 days
# NaT               NaN          NaN       NaT
# NaT               NaN          NaN       NaT
# 4899 days  236.080002  112031800.0 4899 days
# 4900 days  246.720001  147004708.0 4900 days
#
# [4901 rows x 8 columns]

# %%
df['10 days']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '10 days'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[286], line 1
# ----> 1 df['10 days']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '10 days'

# %%
df = pd.read_csv('../data/tesla_stock.csv', parse_dates=[0])

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3373 2023-11-21  235.039993  243.619995  233.339996  241.199997  241.199997
# 3374 2023-11-22  242.039993  244.009995  231.399994  234.210007  234.210007
# 3375 2023-11-24  233.750000  238.750000  232.330002  235.449997  235.449997
# 3376 2023-11-27  236.889999  238.330002  232.100006  236.080002  236.080002
# 3377 2023-11-28  236.679993  247.000000  234.009995  246.720001  246.720001
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...         ...
# 3373  122288000
# 3374  117950600
# 3375   65125200
# 3376  112031800
# 3377  147004708
#
# [3378 rows x 7 columns]

# %%
df.index = df['Date']

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...               ...         ...         ...         ...         ...
# 2023-11-21 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 2023-11-22 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 2023-11-24 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 2023-11-27 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#              Adj Close     Volume
# Date
# 2010-06-29    1.592667  281494500
# 2010-06-30    1.588667  257806500
# 2010-07-01    1.464000  123282000
# 2010-07-02    1.280000   77097000
# 2010-07-06    1.074000  103003500
# ...                ...        ...
# 2023-11-21  241.199997  122288000
# 2023-11-22  234.210007  117950600
# 2023-11-24  235.449997   65125200
# 2023-11-27  236.080002  112031800
# 2023-11-28  246.720001  147004708
#
# [3378 rows x 7 columns]

# %%
df['ref_date'] = df['Date'] - df.index.min()

# %%
df
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 2010-07-02    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...               ...         ...         ...         ...         ...
# 2023-11-21 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 2023-11-22 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 2023-11-24 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 2023-11-27 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#              Adj Close     Volume  ref_date
# Date
# 2010-06-29    1.592667  281494500    0 days
# 2010-06-30    1.588667  257806500    1 days
# 2010-07-01    1.464000  123282000    2 days
# 2010-07-02    1.280000   77097000    3 days
# 2010-07-06    1.074000  103003500    7 days
# ...                ...        ...       ...
# 2023-11-21  241.199997  122288000 4893 days
# 2023-11-22  234.210007  117950600 4894 days
# 2023-11-24  235.449997   65125200 4896 days
# 2023-11-27  236.080002  112031800 4899 days
# 2023-11-28  246.720001  147004708 4900 days
#
# [3378 rows x 8 columns]

# %%
df.index = df['ref_date']

# %%
df
# Out:
#                 Date        Open        High         Low       Close  \
# ref_date
# 0 days    2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1 days    2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2 days    2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3 days    2010-07-02    1.533333    1.540000    1.247333    1.280000
# 7 days    2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...              ...         ...         ...         ...         ...
# 4893 days 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 4894 days 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 4896 days 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 4899 days 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 4900 days 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#             Adj Close     Volume  ref_date
# ref_date
# 0 days       1.592667  281494500    0 days
# 1 days       1.588667  257806500    1 days
# 2 days       1.464000  123282000    2 days
# 3 days       1.280000   77097000    3 days
# 7 days       1.074000  103003500    7 days
# ...               ...        ...       ...
# 4893 days  241.199997  122288000 4893 days
# 4894 days  234.210007  117950600 4894 days
# 4896 days  235.449997   65125200 4896 days
# 4899 days  236.080002  112031800 4899 days
# 4900 days  246.720001  147004708 4900 days
#
# [3378 rows x 8 columns]

# %%
df.loc[0:'10 days']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[300], line 1
# ----> 1 df.loc[0:'10 days']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1290, in _LocIndexer._getitem_axis(self, key, axis)
#    1288 if isinstance(key, slice):
#    1289     self._validate_key(key, axis)
# -> 1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
#    1292     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1321     return obj.copy(deep=False)
#    1323 labels = obj._get_axis(axis)
# -> 1324 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1326 if isinstance(indexer, slice):
#    1327     return self.obj._slice(indexer, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    6516 """
#    6517 Compute the slice indexer for input labels and step.
#    6518
#    (...)
#    6555 slice(1, 3, None)
#    6556 """
#    6557 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6559 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6561 # return a slice
#    6562 if not is_scalar(start_slice):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6767, in Index.slice_locs(self, start, end, step, kind)
#    6765 start_slice = None
#    6766 if start is not None:
# -> 6767     start_slice = self.get_slice_bound(start, "left")
#    6768 if start_slice is None:
#    6769     start_slice = 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6676, in Index.get_slice_bound(self, label, side, kind)
#    6672 original_label = label
#    6674 # For datetime indices label may be a string that has to be converted
#    6675 # to datetime boundary according to its resolution.
# -> 6676 label = self._maybe_cast_slice_bound(label, side)
#    6678 # we need to look up the label
#    6679 try:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\datetimelike.py:320, in DatetimeIndexOpsMixin._maybe_cast_slice_bound(self, label, side, kind)
#     318     return lower if side == "left" else upper
#     319 elif not isinstance(label, self._data._recognized_scalars):
# --> 320     raise self._invalid_indexer("slice", label)
#     322 return label
#
# TypeError: cannot do slice indexing on TimedeltaIndex with these indexers [0] of type int

# %%
df[:'10 days']
# Out:
#                Date      Open      High       Low     Close  Adj Close  \
# ref_date
# 0 days   2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667
# 1 days   2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667
# 2 days   2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000
# 3 days   2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000
# 7 days   2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000
# 8 days   2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333
# 9 days   2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000
# 10 days  2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000
#
#              Volume ref_date
# ref_date
# 0 days    281494500   0 days
# 1 days    257806500   1 days
# 2 days    123282000   2 days
# 3 days     77097000   3 days
# 7 days    103003500   7 days
# 8 days    103825500   8 days
# 9 days    115671000   9 days
# 10 days    60759000  10 days

# %%
dtn = pd.date_range(df.Date.min(), df.Date.max())
dfu = df.copy()

# %%
dfu
# Out:
#                 Date        Open        High         Low       Close  \
# ref_date
# 0 days    2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1 days    2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2 days    2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3 days    2010-07-02    1.533333    1.540000    1.247333    1.280000
# 7 days    2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...              ...         ...         ...         ...         ...
# 4893 days 2023-11-21  235.039993  243.619995  233.339996  241.199997
# 4894 days 2023-11-22  242.039993  244.009995  231.399994  234.210007
# 4896 days 2023-11-24  233.750000  238.750000  232.330002  235.449997
# 4899 days 2023-11-27  236.889999  238.330002  232.100006  236.080002
# 4900 days 2023-11-28  236.679993  247.000000  234.009995  246.720001
#
#             Adj Close     Volume  ref_date
# ref_date
# 0 days       1.592667  281494500    0 days
# 1 days       1.588667  257806500    1 days
# 2 days       1.464000  123282000    2 days
# 3 days       1.280000   77097000    3 days
# 7 days       1.074000  103003500    7 days
# ...               ...        ...       ...
# 4893 days  241.199997  122288000 4893 days
# 4894 days  234.210007  117950600 4894 days
# 4896 days  235.449997   65125200 4896 days
# 4899 days  236.080002  112031800 4899 days
# 4900 days  246.720001  147004708 4900 days
#
# [3378 rows x 8 columns]

# %%
dfu.reindex(dtn)
# Out:
#            Date  Open  High  Low  Close  Adj Close  Volume ref_date
# 2010-06-29  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2010-06-30  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2010-07-01  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2010-07-02  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2010-07-03  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# ...         ...   ...   ...  ...    ...        ...     ...      ...
# 2023-11-24  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2023-11-25  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2023-11-26  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2023-11-27  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
# 2023-11-28  NaT   NaN   NaN  NaN    NaN        NaN     NaN      NaT
#
# [4901 rows x 8 columns]

# %%
df[:'10 days']
# Out:
#                Date      Open      High       Low     Close  Adj Close  \
# ref_date
# 0 days   2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667
# 1 days   2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667
# 2 days   2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000
# 3 days   2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000
# 7 days   2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000
# 8 days   2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333
# 9 days   2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000
# 10 days  2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000
#
#              Volume ref_date
# ref_date
# 0 days    281494500   0 days
# 1 days    257806500   1 days
# 2 days    123282000   2 days
# 3 days     77097000   3 days
# 7 days    103003500   7 days
# 8 days    103825500   8 days
# 9 days    115671000   9 days
# 10 days    60759000  10 days

# %%
dtn
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-03', '2010-07-04', '2010-07-05', '2010-07-06',
#                '2010-07-07', '2010-07-08',
#                ...
#                '2023-11-19', '2023-11-20', '2023-11-21', '2023-11-22',
#                '2023-11-23', '2023-11-24', '2023-11-25', '2023-11-26',
#                '2023-11-27', '2023-11-28'],
#               dtype='datetime64[ns]', length=4901, freq='D')

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
df10 = df.sample(10)

# %%
df10
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 6  2014-12-27  280        2695.0            NaN             9409.0
# 42 2014-10-07  199        1350.0         4076.0                NaN
# 24 2014-11-09  232        1878.0            NaN             5368.0
# 93 2014-05-12   51         248.0           12.0                0.0
# 31 2014-10-27  218        1906.0            NaN             5235.0
# 95 2014-05-07   46         236.0           13.0                0.0
# 33 2014-10-22  214           NaN            NaN             3896.0
# 70 2014-07-27  126         460.0          329.0              533.0
# 77 2014-07-06  106         408.0          131.0              305.0
# 66 2014-08-06  137         495.0          554.0              717.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 6             NaN            NaN                 NaN          NaN         NaN
# 42            NaN            NaN                 NaN          NaN         NaN
# 24           20.0            1.0                 4.0          1.0         1.0
# 93            NaN            NaN                 NaN          NaN         NaN
# 31           20.0            1.0                 4.0          1.0         1.0
# 95            NaN            NaN                 NaN          NaN         NaN
# 33            NaN            NaN                 4.0          1.0         1.0
# 70            1.0            NaN                 NaN          NaN         NaN
# 77            NaN            NaN                 NaN          NaN         NaN
# 66           13.0            NaN                 NaN          NaN         NaN
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 6          1697.0             NaN              2732.0             NaN
# 42          778.0          2316.0                 NaN             NaN
# 24         1142.0             NaN              1169.0             8.0
# 93          171.0            11.0                 0.0             NaN
# 31          997.0             NaN              1500.0             8.0
# 95          158.0            11.0                 0.0             NaN
# 33            NaN             NaN              1281.0             NaN
# 70          339.0           156.0               233.0             1.0
# 77          307.0            84.0               127.0             NaN
# 66          367.0           294.0               298.0             2.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 6              NaN                  NaN           NaN          NaN
# 42             NaN                  NaN           NaN          NaN
# 24             0.0                  1.0           0.0          1.0
# 93             NaN                  NaN           NaN          NaN
# 31             0.0                  1.0           0.0          1.0
# 95             NaN                  NaN           NaN          NaN
# 33             NaN                  1.0           0.0          1.0
# 70             NaN                  NaN           NaN          NaN
# 77             NaN                  NaN           NaN          NaN
# 66             NaN                  NaN           NaN          NaN

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 6 to 66
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10 non-null     datetime64[ns]
#  1   Day                  10 non-null     int64
#  2   Cases_Guinea         9 non-null      float64
#  3   Cases_Liberia        6 non-null      float64
#  4   Cases_SierraLeone    9 non-null      float64
#  5   Cases_Nigeria        4 non-null      float64
#  6   Cases_Senegal        2 non-null      float64
#  7   Cases_UnitedStates   3 non-null      float64
#  8   Cases_Spain          3 non-null      float64
#  9   Cases_Mali           3 non-null      float64
#  10  Deaths_Guinea        9 non-null      float64
#  11  Deaths_Liberia       6 non-null      float64
#  12  Deaths_SierraLeone   9 non-null      float64
#  13  Deaths_Nigeria       4 non-null      float64
#  14  Deaths_Senegal       2 non-null      float64
#  15  Deaths_UnitedStates  3 non-null      float64
#  16  Deaths_Spain         3 non-null      float64
#  17  Deaths_Mali          3 non-null      float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 1.5 KB

# %%
df10
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 6  2014-12-27  280        2695.0            NaN             9409.0
# 42 2014-10-07  199        1350.0         4076.0                NaN
# 24 2014-11-09  232        1878.0            NaN             5368.0
# 93 2014-05-12   51         248.0           12.0                0.0
# 31 2014-10-27  218        1906.0            NaN             5235.0
# 95 2014-05-07   46         236.0           13.0                0.0
# 33 2014-10-22  214           NaN            NaN             3896.0
# 70 2014-07-27  126         460.0          329.0              533.0
# 77 2014-07-06  106         408.0          131.0              305.0
# 66 2014-08-06  137         495.0          554.0              717.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 6             NaN            NaN                 NaN          NaN         NaN
# 42            NaN            NaN                 NaN          NaN         NaN
# 24           20.0            1.0                 4.0          1.0         1.0
# 93            NaN            NaN                 NaN          NaN         NaN
# 31           20.0            1.0                 4.0          1.0         1.0
# 95            NaN            NaN                 NaN          NaN         NaN
# 33            NaN            NaN                 4.0          1.0         1.0
# 70            1.0            NaN                 NaN          NaN         NaN
# 77            NaN            NaN                 NaN          NaN         NaN
# 66           13.0            NaN                 NaN          NaN         NaN
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 6          1697.0             NaN              2732.0             NaN
# 42          778.0          2316.0                 NaN             NaN
# 24         1142.0             NaN              1169.0             8.0
# 93          171.0            11.0                 0.0             NaN
# 31          997.0             NaN              1500.0             8.0
# 95          158.0            11.0                 0.0             NaN
# 33            NaN             NaN              1281.0             NaN
# 70          339.0           156.0               233.0             1.0
# 77          307.0            84.0               127.0             NaN
# 66          367.0           294.0               298.0             2.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 6              NaN                  NaN           NaN          NaN
# 42             NaN                  NaN           NaN          NaN
# 24             0.0                  1.0           0.0          1.0
# 93             NaN                  NaN           NaN          NaN
# 31             0.0                  1.0           0.0          1.0
# 95             NaN                  NaN           NaN          NaN
# 33             NaN                  1.0           0.0          1.0
# 70             NaN                  NaN           NaN          NaN
# 77             NaN                  NaN           NaN          NaN
# 66             NaN                  NaN           NaN          NaN

# %%
df10.index = df10['Date']

# %%
df10
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-12-27 2014-12-27  280        2695.0            NaN             9409.0
# 2014-10-07 2014-10-07  199        1350.0         4076.0                NaN
# 2014-11-09 2014-11-09  232        1878.0            NaN             5368.0
# 2014-05-12 2014-05-12   51         248.0           12.0                0.0
# 2014-10-27 2014-10-27  218        1906.0            NaN             5235.0
# 2014-05-07 2014-05-07   46         236.0           13.0                0.0
# 2014-10-22 2014-10-22  214           NaN            NaN             3896.0
# 2014-07-27 2014-07-27  126         460.0          329.0              533.0
# 2014-07-06 2014-07-06  106         408.0          131.0              305.0
# 2014-08-06 2014-08-06  137         495.0          554.0              717.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2014-12-27            NaN            NaN                 NaN          NaN
# 2014-10-07            NaN            NaN                 NaN          NaN
# 2014-11-09           20.0            1.0                 4.0          1.0
# 2014-05-12            NaN            NaN                 NaN          NaN
# 2014-10-27           20.0            1.0                 4.0          1.0
# 2014-05-07            NaN            NaN                 NaN          NaN
# 2014-10-22            NaN            NaN                 4.0          1.0
# 2014-07-27            1.0            NaN                 NaN          NaN
# 2014-07-06            NaN            NaN                 NaN          NaN
# 2014-08-06           13.0            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2014-12-27         NaN         1697.0             NaN              2732.0
# 2014-10-07         NaN          778.0          2316.0                 NaN
# 2014-11-09         1.0         1142.0             NaN              1169.0
# 2014-05-12         NaN          171.0            11.0                 0.0
# 2014-10-27         1.0          997.0             NaN              1500.0
# 2014-05-07         NaN          158.0            11.0                 0.0
# 2014-10-22         1.0            NaN             NaN              1281.0
# 2014-07-27         NaN          339.0           156.0               233.0
# 2014-07-06         NaN          307.0            84.0               127.0
# 2014-08-06         NaN          367.0           294.0               298.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2014-12-27             NaN             NaN                  NaN           NaN
# 2014-10-07             NaN             NaN                  NaN           NaN
# 2014-11-09             8.0             0.0                  1.0           0.0
# 2014-05-12             NaN             NaN                  NaN           NaN
# 2014-10-27             8.0             0.0                  1.0           0.0
# 2014-05-07             NaN             NaN                  NaN           NaN
# 2014-10-22             NaN             NaN                  1.0           0.0
# 2014-07-27             1.0             NaN                  NaN           NaN
# 2014-07-06             NaN             NaN                  NaN           NaN
# 2014-08-06             2.0             NaN                  NaN           NaN
#
#             Deaths_Mali
# Date
# 2014-12-27          NaN
# 2014-10-07          NaN
# 2014-11-09          1.0
# 2014-05-12          NaN
# 2014-10-27          1.0
# 2014-05-07          NaN
# 2014-10-22          1.0
# 2014-07-27          NaN
# 2014-07-06          NaN
# 2014-08-06          NaN

# %%
dfu = pd.date_range(df10.index.min(), df10.index.max())
dfu
# Out:
# DatetimeIndex(['2014-05-07', '2014-05-08', '2014-05-09', '2014-05-10',
#                '2014-05-11', '2014-05-12', '2014-05-13', '2014-05-14',
#                '2014-05-15', '2014-05-16',
#                ...
#                '2014-12-18', '2014-12-19', '2014-12-20', '2014-12-21',
#                '2014-12-22', '2014-12-23', '2014-12-24', '2014-12-25',
#                '2014-12-26', '2014-12-27'],
#               dtype='datetime64[ns]', length=235, freq='D')

# %%
df10 = df10.reindex(dfu)

# %%
df10
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 2014-05-07 2014-05-07   46.0         236.0           13.0                0.0
# 2014-05-08        NaT    NaN           NaN            NaN                NaN
# 2014-05-09        NaT    NaN           NaN            NaN                NaN
# 2014-05-10        NaT    NaN           NaN            NaN                NaN
# 2014-05-11        NaT    NaN           NaN            NaN                NaN
# ...               ...    ...           ...            ...                ...
# 2014-12-23        NaT    NaN           NaN            NaN                NaN
# 2014-12-24        NaT    NaN           NaN            NaN                NaN
# 2014-12-25        NaT    NaN           NaN            NaN                NaN
# 2014-12-26        NaT    NaN           NaN            NaN                NaN
# 2014-12-27 2014-12-27  280.0        2695.0            NaN             9409.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 2014-05-07            NaN            NaN                 NaN          NaN
# 2014-05-08            NaN            NaN                 NaN          NaN
# 2014-05-09            NaN            NaN                 NaN          NaN
# 2014-05-10            NaN            NaN                 NaN          NaN
# 2014-05-11            NaN            NaN                 NaN          NaN
# ...                   ...            ...                 ...          ...
# 2014-12-23            NaN            NaN                 NaN          NaN
# 2014-12-24            NaN            NaN                 NaN          NaN
# 2014-12-25            NaN            NaN                 NaN          NaN
# 2014-12-26            NaN            NaN                 NaN          NaN
# 2014-12-27            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 2014-05-07         NaN          158.0            11.0                 0.0
# 2014-05-08         NaN            NaN             NaN                 NaN
# 2014-05-09         NaN            NaN             NaN                 NaN
# 2014-05-10         NaN            NaN             NaN                 NaN
# 2014-05-11         NaN            NaN             NaN                 NaN
# ...                ...            ...             ...                 ...
# 2014-12-23         NaN            NaN             NaN                 NaN
# 2014-12-24         NaN            NaN             NaN                 NaN
# 2014-12-25         NaN            NaN             NaN                 NaN
# 2014-12-26         NaN            NaN             NaN                 NaN
# 2014-12-27         NaN         1697.0             NaN              2732.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 2014-05-07             NaN             NaN                  NaN           NaN
# 2014-05-08             NaN             NaN                  NaN           NaN
# 2014-05-09             NaN             NaN                  NaN           NaN
# 2014-05-10             NaN             NaN                  NaN           NaN
# 2014-05-11             NaN             NaN                  NaN           NaN
# ...                    ...             ...                  ...           ...
# 2014-12-23             NaN             NaN                  NaN           NaN
# 2014-12-24             NaN             NaN                  NaN           NaN
# 2014-12-25             NaN             NaN                  NaN           NaN
# 2014-12-26             NaN             NaN                  NaN           NaN
# 2014-12-27             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# 2014-05-07          NaN
# 2014-05-08          NaN
# 2014-05-09          NaN
# 2014-05-10          NaN
# 2014-05-11          NaN
# ...                 ...
# 2014-12-23          NaN
# 2014-12-24          NaN
# 2014-12-25          NaN
# 2014-12-26          NaN
# 2014-12-27          NaN
#
# [235 rows x 18 columns]

# %%
pd.date_range('2000-01-01', '2023-12-19', freq='W')
# Out:
# DatetimeIndex(['2000-01-02', '2000-01-09', '2000-01-16', '2000-01-23',
#                '2000-01-30', '2000-02-06', '2000-02-13', '2000-02-20',
#                '2000-02-27', '2000-03-05',
#                ...
#                '2023-10-15', '2023-10-22', '2023-10-29', '2023-11-05',
#                '2023-11-12', '2023-11-19', '2023-11-26', '2023-12-03',
#                '2023-12-10', '2023-12-17'],
#               dtype='datetime64[ns]', length=1251, freq='W-SUN')

# %%
pd.date_range('2000-01-01', '2023-12-19', freq='B')
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2023-12-06', '2023-12-07', '2023-12-08', '2023-12-11',
#                '2023-12-12', '2023-12-13', '2023-12-14', '2023-12-15',
#                '2023-12-18', '2023-12-19'],
#               dtype='datetime64[ns]', length=6252, freq='B')

# %%
# b는 평일
# w는 주간

# %%
pd.date_range('2000-01-01', '2023-12-19', freq='W')
# Out:
# DatetimeIndex(['2000-01-02', '2000-01-09', '2000-01-16', '2000-01-23',
#                '2000-01-30', '2000-02-06', '2000-02-13', '2000-02-20',
#                '2000-02-27', '2000-03-05',
#                ...
#                '2023-10-15', '2023-10-22', '2023-10-29', '2023-11-05',
#                '2023-11-12', '2023-11-19', '2023-11-26', '2023-12-03',
#                '2023-12-10', '2023-12-17'],
#               dtype='datetime64[ns]', length=1251, freq='W-SUN')

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=['Date'])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
df[:0, 1:].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, 0, None), slice(1, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[330], line 1
# ----> 1 df[:0, 1:].plot()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key, method, tolerance)
#    3804         raise KeyError(key) from err
#    3805     except TypeError:
#    3806         # If we have a listlike key, _check_indexing_error will raise
#    3807         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808         #  the TypeError.
# -> 3809         self._check_indexing_error(key)
#    3810         raise
#    3812 # GH#42269
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5925, in Index._check_indexing_error(self, key)
#    5921 def _check_indexing_error(self, key):
#    5922     if not is_scalar(key):
#    5923         # if key is not a scalar, directly raise an error (the code below
#    5924         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, 0, None), slice(1, None, None))

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
df.index = df['Date']

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22 2014-03-22    0          49.0            NaN                NaN
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
# ...                   ...            ...                 ...          ...
# 2014-03-27            NaN            NaN                 NaN          NaN
# 2014-03-26            NaN            NaN                 NaN          NaN
# 2014-03-25            NaN            NaN                 NaN          NaN
# 2014-03-24            NaN            NaN                 NaN          NaN
# 2014-03-22            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2015-01-05         NaN         1786.0             NaN              2977.0
# 2015-01-04         NaN         1781.0             NaN              2943.0
# 2015-01-03         NaN         1767.0          3496.0              2915.0
# 2015-01-02         NaN            NaN          3496.0                 NaN
# 2014-12-31         NaN         1739.0          3471.0              2827.0
# ...                ...            ...             ...                 ...
# 2014-03-27         NaN           66.0             6.0                 5.0
# 2014-03-26         NaN           62.0             NaN                 NaN
# 2014-03-25         NaN           60.0             NaN                 NaN
# 2014-03-24         NaN           59.0             NaN                 NaN
# 2014-03-22         NaN           29.0             NaN                 NaN
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2015-01-05             NaN             NaN                  NaN           NaN
# 2015-01-04             NaN             NaN                  NaN           NaN
# 2015-01-03             NaN             NaN                  NaN           NaN
# 2015-01-02             NaN             NaN                  NaN           NaN
# 2014-12-31             NaN             NaN                  NaN           NaN
# ...                    ...             ...                  ...           ...
# 2014-03-27             NaN             NaN                  NaN           NaN
# 2014-03-26             NaN             NaN                  NaN           NaN
# 2014-03-25             NaN             NaN                  NaN           NaN
# 2014-03-24             NaN             NaN                  NaN           NaN
# 2014-03-22             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# Date
# 2015-01-05          NaN
# 2015-01-04          NaN
# 2015-01-03          NaN
# 2015-01-02          NaN
# 2014-12-31          NaN
# ...                 ...
# 2014-03-27          NaN
# 2014-03-26          NaN
# 2014-03-25          NaN
# 2014-03-24          NaN
# 2014-03-22          NaN
#
# [122 rows x 18 columns]

# %%
fig = df.iloc[0:, 1:].plot()
fig.legend(fontsize=7, loc=2)

# %%
# seaborn
fig = sns.lineplot(data=df.iloc[0:, 1:])
fig.legend(prop={'size':7})
fig.set_xticklabels(fig.get_xticklabels(), rotation = 45)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_8596\1204434510.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.set_xticklabels(fig.get_xticklabels(), rotation = 45)
# [Text(16161.0, 0, '2014-04'),
#  Text(16191.0, 0, '2014-05'),
#  Text(16222.0, 0, '2014-06'),
#  Text(16252.0, 0, '2014-07'),
#  Text(16283.0, 0, '2014-08'),
#  Text(16314.0, 0, '2014-09'),
#  Text(16344.0, 0, '2014-10'),
#  Text(16375.0, 0, '2014-11'),
#  Text(16405.0, 0, '2014-12'),
#  Text(16436.0, 0, '2015-01')]
