# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df.index = df['Date']

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22 2014-03-22    0          49.0            NaN                NaN
#
# ...

# %%
df_range = pd.date_range(df.index.min(), df.index.max())
df_range
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', length=290, freq='D')

# %%
df_range = reversed(df_range)

# %%
df.reindex(df_range)
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
# ...               ...    ...           ...            ...                ...
# 2014-03-26 2014-03-26    4.0          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2.0          86.0            NaN                NaN
# 2014-03-23        NaT    NaN           NaN            NaN                NaN
# 2014-03-22 2014-03-22    0.0          49.0            NaN                NaN
#
# ...

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22 2014-03-22    0          49.0            NaN                NaN
#
# ...

# %%
diff = df.apply(pd.Series.last_valid_index) - df.index.min()

# %%
diff
# Out:
# Date                    0 days
# Day                     0 days
# Cases_Guinea            0 days
# Cases_Liberia           5 days
# Cases_SierraLeone       5 days
# Cases_Nigeria         123 days
# Cases_Senegal         162 days
# Cases_UnitedStates    193 days
# Cases_Spain           200 days
# Cases_Mali            214 days
# Deaths_Guinea           0 days
# Deaths_Liberia          5 days
# Deaths_SierraLeone      5 days
# Deaths_Nigeria        123 days
# Deaths_Senegal        169 days
# Deaths_UnitedStates   193 days
# Deaths_Spain          200 days
# Deaths_Mali           214 days
# dtype: timedelta64[ns]

# %%
dt_dict = {}
for i,v in enumerate(df):
    dt_dict[v] = df[v].shift(diff[i].days)

# %%
dt_dict
# Out:
# {'Date': Date
#  2015-01-05   2015-01-05
#  2015-01-04   2015-01-04
#  2015-01-03   2015-01-03
#  2015-01-02   2015-01-02
#  2014-12-31   2014-12-31
#                  ...
#  2014-03-27   2014-03-27
#  2014-03-26   2014-03-26
#  2014-03-25   2014-03-25
#  2014-03-24   2014-03-24
#  2014-03-22   2014-03-22
#  Name: Date, Length: 122, dtype: datetime64[ns],
#  'Day': Date
#  2015-01-05    289
#  2015-01-04    288
#  2015-01-03    287
#  2015-01-02    286
#  2014-12-31    284
#               ...
#  2014-03-27      5
#  2014-03-26      4
#  2014-03-25      3
#  2014-03-24      2
#  2014-03-22      0
#  Name: Day, Length: 122, dtype: int64,
#  'Cases_Guinea': Date
#  2015-01-05    2776.0
#  2015-01-04    2775.0
#  2015-01-03    2769.0
#  2015-01-02       NaN
#  2014-12-31    2730.0
#                 ...
#  2014-03-27     103.0
#  2014-03-26      86.0
#  2014-03-25      86.0
#  2014-03-24      86.0
#  2014-03-22      49.0
#  Name: Cases_Guinea, Length: 122, dtype: float64,
# ...

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22 2014-03-22    0          49.0            NaN                NaN
#
# ...

# %%
df = pd.DataFrame(dt_dict)

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN                NaN
# 2015-01-04 2015-01-04  288        2775.0            NaN                NaN
# 2015-01-03 2015-01-03  287        2769.0            NaN                NaN
# 2015-01-02 2015-01-02  286           NaN            NaN                NaN
# 2014-12-31 2014-12-31  284        2730.0            NaN                NaN
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0           18.0                2.0
# 2014-03-26 2014-03-26    4          86.0            8.0                2.0
# 2014-03-25 2014-03-25    3          86.0            8.0                2.0
# 2014-03-24 2014-03-24    2          86.0            7.0                NaN
# 2014-03-22 2014-03-22    0          49.0            3.0                2.0
#
# ...

# %%
df.index = df.Day

# %%
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Day
# 289 2015-01-05  289        2776.0            NaN                NaN
# 288 2015-01-04  288        2775.0            NaN                NaN
# 287 2015-01-03  287        2769.0            NaN                NaN
# 286 2015-01-02  286           NaN            NaN                NaN
# 284 2014-12-31  284        2730.0            NaN                NaN
# ..         ...  ...           ...            ...                ...
# 5   2014-03-27    5         103.0           18.0                2.0
# 4   2014-03-26    4          86.0            8.0                2.0
# 3   2014-03-25    3          86.0            8.0                2.0
# 2   2014-03-24    2          86.0            7.0                NaN
# 0   2014-03-22    0          49.0            3.0                2.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Day
# 289            NaN            NaN                 NaN          NaN
# ...

# %%
df = df.drop(['Date', 'Day'], axis=1)

# %%
df
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 289        2776.0            NaN                NaN            NaN
# 288        2775.0            NaN                NaN            NaN
# 287        2769.0            NaN                NaN            NaN
# 286           NaN            NaN                NaN            NaN
# 284        2730.0            NaN                NaN            NaN
# ..            ...            ...                ...            ...
# 5           103.0           18.0                2.0            NaN
# 4            86.0            8.0                2.0            NaN
# 3            86.0            8.0                2.0            NaN
# 2            86.0            7.0                NaN            NaN
# 0            49.0            3.0                2.0            NaN
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 289            NaN                 NaN          NaN         NaN
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='Day'>

# %%
sns.lineplot(df)
# Out:
# <Axes: xlabel='Day'>

# %%
df = pd.read_csv('../data/country_timeseries.csv', parse_dates=[0])
df
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df.index = df['Date']

# %%
df
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22 2014-03-22    0          49.0            NaN                NaN
#
# ...

# %%
new_idx = pd.date_range(df.index.min(), df.index.max())

# %%
new_idx
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', length=290, freq='D')

# %%
new_idx = reversed(new_idx)

# %%
new_idx

# %%
last_valid = df.apply(pd.Series.last_valid_index)
shift_values = last_valid - df.index.min()

# %%
shift_values
# Out:
# Date                    0 days
# Day                     0 days
# Cases_Guinea            0 days
# Cases_Liberia           5 days
# Cases_SierraLeone       5 days
# Cases_Nigeria         123 days
# Cases_Senegal         162 days
# Cases_UnitedStates    193 days
# Cases_Spain           200 days
# Cases_Mali            214 days
# Deaths_Guinea           0 days
# Deaths_Liberia          5 days
# Deaths_SierraLeone      5 days
# Deaths_Nigeria        123 days
# Deaths_Senegal        169 days
# Deaths_UnitedStates   193 days
# Deaths_Spain          200 days
# Deaths_Mali           214 days
# dtype: timedelta64[ns]

# %%
df_dict = {}
for i, v in enumerate(df):
    df_dict[v] = df[v].shift(shift_values[i].days)
df_dict
# Out:
# {'Date': Date
#  2015-01-05   2015-01-05
#  2015-01-04   2015-01-04
#  2015-01-03   2015-01-03
#  2015-01-02   2015-01-02
#  2014-12-31   2014-12-31
#                  ...
#  2014-03-27   2014-03-27
#  2014-03-26   2014-03-26
#  2014-03-25   2014-03-25
#  2014-03-24   2014-03-24
#  2014-03-22   2014-03-22
#  Name: Date, Length: 122, dtype: datetime64[ns],
#  'Day': Date
#  2015-01-05    289
#  2015-01-04    288
#  2015-01-03    287
#  2015-01-02    286
#  2014-12-31    284
#               ...
#  2014-03-27      5
#  2014-03-26      4
#  2014-03-25      3
#  2014-03-24      2
#  2014-03-22      0
#  Name: Day, Length: 122, dtype: int64,
#  'Cases_Guinea': Date
#  2015-01-05    2776.0
#  2015-01-04    2775.0
#  2015-01-03    2769.0
#  2015-01-02       NaN
#  2014-12-31    2730.0
#                 ...
#  2014-03-27     103.0
#  2014-03-26      86.0
#  2014-03-25      86.0
#  2014-03-24      86.0
#  2014-03-22      49.0
#  Name: Cases_Guinea, Length: 122, dtype: float64,
# ...

# %%
df_n = pd.DataFrame(df_dict)

# %%
df_n
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN                NaN
# 2015-01-04 2015-01-04  288        2775.0            NaN                NaN
# 2015-01-03 2015-01-03  287        2769.0            NaN                NaN
# 2015-01-02 2015-01-02  286           NaN            NaN                NaN
# 2014-12-31 2014-12-31  284        2730.0            NaN                NaN
# ...               ...  ...           ...            ...                ...
# 2014-03-27 2014-03-27    5         103.0           18.0                2.0
# 2014-03-26 2014-03-26    4          86.0            8.0                2.0
# 2014-03-25 2014-03-25    3          86.0            8.0                2.0
# 2014-03-24 2014-03-24    2          86.0            7.0                NaN
# 2014-03-22 2014-03-22    0          49.0            3.0                2.0
#
# ...

# %%
df_n.index = df_n['Day']

# %%
df_n
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Day
# 289 2015-01-05  289        2776.0            NaN                NaN
# 288 2015-01-04  288        2775.0            NaN                NaN
# 287 2015-01-03  287        2769.0            NaN                NaN
# 286 2015-01-02  286           NaN            NaN                NaN
# 284 2014-12-31  284        2730.0            NaN                NaN
# ..         ...  ...           ...            ...                ...
# 5   2014-03-27    5         103.0           18.0                2.0
# 4   2014-03-26    4          86.0            8.0                2.0
# 3   2014-03-25    3          86.0            8.0                2.0
# 2   2014-03-24    2          86.0            7.0                NaN
# 0   2014-03-22    0          49.0            3.0                2.0
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Day
# 289            NaN            NaN                 NaN          NaN
# ...

# %%
df_n = df_n.drop(['Date', 'Day'], axis=1)

# %%
df_n
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 289        2776.0            NaN                NaN            NaN
# 288        2775.0            NaN                NaN            NaN
# 287        2769.0            NaN                NaN            NaN
# 286           NaN            NaN                NaN            NaN
# 284        2730.0            NaN                NaN            NaN
# ..            ...            ...                ...            ...
# 5           103.0           18.0                2.0            NaN
# 4            86.0            8.0                2.0            NaN
# 3            86.0            8.0                2.0            NaN
# 2            86.0            7.0                NaN            NaN
# 0            49.0            3.0                2.0            NaN
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 289            NaN                 NaN          NaN         NaN
# ...
