# %%
import pandas as pd

# %%
df = pd.read_csv('../data/starrail.csv')
df.head()
# Out:
#    character  rarity          path combat_type  wb_b-atk  wb_skill  wb_ult  \
# 0  march_7th       4  preservation         ice        30         0      60
# 1   dan_heng       4          hunt        wind        30        60      90
# 2     himeko       5     erudition        fire        30        60      60
# 3       welt       5      nihility   imaginary        30        30      60
# 4      kafka       5      nihility   lightning        30        60      60
#
#    er_b-atk  er_skill  er_ult  ...  hp_40  atk_20a  def_20a  hp_20a  atk_20  \
# 0        20        30       5  ...    540   163.56   183.30     338  135.72
# 1        20        30       5  ...    450   174.84   126.90     282  145.08
# 2        20        10       5  ...    535   241.96   139.59     335  200.77
# 3        20        30       5  ...    574   198.53   162.86     360  164.74
# 4        20        30       5  ...    554   217.14   155.10     347  180.18
#
#    def_20  hp_20   atk_1  def_1  hp_1
# ...

# %%
df
# Out:
#         character  rarity          path combat_type  wb_b-atk  wb_skill  \
# 0       march_7th       4  preservation         ice        30         0
# 1        dan_heng       4          hunt        wind        30        60
# 2          himeko       5     erudition        fire        30        60
# 3            welt       5      nihility   imaginary        30        30
# 4           kafka       5      nihility   lightning        30        60
# 5     silver_wolf       5      nihility     quantum        30        60
# 6           arlan       4   destruction   lightning        30        60
# 7            asta       4       harmony        fire        30        30
# 8           herta       4     erudition         ice        30        30
# 9          bronya       5       harmony        wind        30         0
# 10          seele       5          hunt     quantum        30        60
# 11         serval       4     erudition   lightning        30        60
# ...

# %%
df.columns
# Out:
# Index(['character', 'rarity', 'path', 'combat_type', 'wb_b-atk', 'wb_skill',
#        'wb_ult', 'er_b-atk', 'er_skill', 'er_ult', 'spd', 'crit-r', 'crit-d',
#        'taunt', 'max_energy', 'atk_80', 'def_80', 'hp_80', 'atk_70a',
#        'def_70a', 'hp_70a', 'atk_70', 'def_70', 'hp_70', 'atk_60a', 'def_60a',
#        'hp_60a', 'atk_60', 'def_60', 'hp_60', 'atk_50a', 'def_50a', 'hp_50a',
#        'atk_50', 'def_50', 'hp_50', 'atk_40a', 'def_40a', 'hp_40a', 'atk_40',
#        'def_40', 'hp_40', 'atk_20a', 'def_20a', 'hp_20a', 'atk_20', 'def_20',
#        'hp_20', 'atk_1', 'def_1', 'hp_1'],
#       dtype='object')

# %%
ax = sns.FacetGrid(df, col='combat_type', row='rarity')
ax.map(sns.scatterplot, "atk_80", "def_80")

# %%
import seaborn as sns

# %%
sns.countplot(x='combat_type', data=df)
# Out:
# <Axes: xlabel='combat_type', ylabel='count'>

# %%
sns.histplot(x='rarity', y='combat_type', data=df)
# Out:
# <Axes: xlabel='rarity', ylabel='combat_type'>

# %%
df.columns
# Out:
# Index(['character', 'rarity', 'path', 'combat_type', 'wb_b-atk', 'wb_skill',
#        'wb_ult', 'er_b-atk', 'er_skill', 'er_ult', 'spd', 'crit-r', 'crit-d',
#        'taunt', 'max_energy', 'atk_80', 'def_80', 'hp_80', 'atk_70a',
#        'def_70a', 'hp_70a', 'atk_70', 'def_70', 'hp_70', 'atk_60a', 'def_60a',
#        'hp_60a', 'atk_60', 'def_60', 'hp_60', 'atk_50a', 'def_50a', 'hp_50a',
#        'atk_50', 'def_50', 'hp_50', 'atk_40a', 'def_40a', 'hp_40a', 'atk_40',
#        'def_40', 'hp_40', 'atk_20a', 'def_20a', 'hp_20a', 'atk_20', 'def_20',
#        'hp_20', 'atk_1', 'def_1', 'hp_1'],
#       dtype='object')

# %%
sns.histplot(x='combat_type', y='character', data=df)
# Out:
# <Axes: xlabel='combat_type', ylabel='character'>

# %%
sns.countplot(x='path', data=df)
# Out:
# <Axes: xlabel='path', ylabel='count'>

# %%
sns.barplot(x='hp_40', y='character', data=df)
# Out:
# <Axes: xlabel='hp_40', ylabel='character'>
