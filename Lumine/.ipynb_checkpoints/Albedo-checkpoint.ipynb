# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.FacetGrid(df, col='day', row='time')
ax.map(sns.boxplot, 'total_bill', 'tip')
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
ax = sns.FacetGrid(df, col='day', row='time')
ax.map(sns.histplot, 'total_bill', 'tip')

# %%
ax = sns.FacetGrid(df, col='day', row='time', hue='size')
ax.map(sns.scatterplot, 'total_bill', 'tip')

# %%
ax = sns.FacetGrid(df, col='day', row='time', hue='size')
ax.map(sns.barplot, 'total_bill', 'tip')
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
ax = sns.FacetGrid(df, col='day', row='time', hue='sex')
ax.map(sns.scatterplot, 'smoker', 'tip')

# %%
ax = sns.FacetGrid(df, col='day', row='time', hue='sex')
ax.map(sns.barplot, 'smoker', 'tip', errorbar=None)
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.histplot(x='smoker', y='sex', data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>
