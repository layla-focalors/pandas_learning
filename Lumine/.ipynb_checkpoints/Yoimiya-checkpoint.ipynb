# %%
import pandas as pd

# %%
df = pd.read_excel('../data/genshin.xlsx')
df.head()
# Out:
#   character_name  rarity     region  vision weapon_type          model  \
# 0         Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1      Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2           Aloy       5        NaN    Cryo         Bow  Medium Female
# 3          Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4   Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
#
#         constellation             birthday                special_dish  \
# 0  Princeps Cretaceus  2023-09-13 00:00:00              Woodland Dream
# 1       Vultur Volans  2023-02-11 00:00:00          Ideal Circumstance
# 2         Nora Fortis  2023-04-04 00:00:00                 Satiety Gel
# 3               Lepus  2023-08-10 00:00:00  Outrider's Champion Steak!
# 4    Taurus Iracundus  2023-06-01 00:00:00           Way of the Strong
#
#            affiliation  ... hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1  \
# ...

# %%
df.describe()
# Out:
#           rarity      hp_90_90   atk_90_90   def_90_90      hp_80_90  \
# count  72.000000     72.000000   72.000000   72.000000     72.000000
# mean    4.500000  11717.055556  248.347222  702.958333  11024.402778
# std     0.503509   1647.876798   52.213581   95.662028   1940.139778
# min     4.000000   9189.000000  106.000000  499.000000   8553.000000
# 25%     4.000000  10352.750000  212.000000  629.500000   9627.250000
# 50%     4.500000  11908.000000  234.000000  705.500000  11083.000000
# 75%     5.000000  12925.500000  297.250000  769.500000  12017.000000
# max     5.000000  15674.000000  349.000000  959.000000  21080.000000
#
#         atk_80_90   def_80_90      hp_80_80   atk_80_80   def_80_80  ...  \
# count   72.000000   72.000000     72.000000   72.000000   72.000000  ...
# mean   230.986111  653.944444  10360.680556  219.541667  621.583333  ...
# std     48.410362   88.928186   1445.054293   45.789149   84.304069  ...
# ...

# %%
df.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'hp_90_90', 'atk_90_90', 'def_90_90',
#        'hp_80_90', 'atk_80_90', 'def_80_90', 'hp_80_80', 'atk_80_80',
#        'def_80_80', 'hp_70_80', 'atk_70_80', 'def_70_80', 'hp_70_70',
#        'atk_70_70', 'def_70_70', 'hp_60_70', 'atk_60_70', 'def_60_70',
#        'hp_60_60', 'atk_60_60', 'def_60_60', 'hp_50_60', 'atk_50_60',
#        'def_50_60', 'hp_50_50', 'atk_50_50', 'def_50_50', 'hp_40_50',
#        'atk_40_50', 'def_40_50', 'hp_40_40', 'atk_40_40', 'def_40_40',
#        'hp_20_40', 'atk_20_40', 'def_20_40', 'hp_20_20', 'atk_20_20',
#        'def_20_20', 'hp_1_20', 'atk_1_20', 'def_1_20', 'spsecial_0',
# ...

# %%
melted = pd.melt(df, id_vars=['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
       'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
       'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
       'ascension_specialty', 'ascension_talent', 'ascension_boss',
       'talent_book', 'talent_weekly'], var_name="stats", value_name="data") 
melted
# Out:
#      character_name  rarity     region  vision weapon_type          model  \
# 0            Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1         Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2              Aloy       5        NaN    Cryo         Bow  Medium Female
# 3             Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4      Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ...             ...     ...        ...     ...         ...            ...
# 3523         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 3524          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 3525        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 3526        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 3527        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#            constellation             birthday                   special_dish  \
# ...

# %%
df.shape
# Out:
# (72, 70)

# %%
melted.shape
# Out:
# (3528, 23)

# %%
melted.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'stats', 'data'],
#       dtype='object')

# %%
melted['id'] = range(len(melted))

# %%
melted.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'stats', 'data', 'id'],
#       dtype='object')

# %%
df = pd.pivot_table(melted, index=['id','character_name','rarity', 'region', 'vision'], columns='stats') 
df
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_10008\2729919988.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df = pd.pivot_table(melted, index=['id','character_name','rarity', 'region', 'vision'], columns='stats')
#                                                 data                      \
# stats                                       atk_1_20 atk_20_20 atk_20_40
# id   character_name rarity region    vision
# 0    Albedo         5      Mondstadt Geo         NaN       NaN       NaN
# 1    Alhaitham      5      Sumeru    Dendro      NaN       NaN       NaN
# 3    Amber          4      Mondstadt Pyro        NaN       NaN       NaN
# 4    Arataki Itto   5      Inazuma   Geo         NaN       NaN       NaN
# 5    Baizhu         5      Liyue     Dendro      NaN       NaN       NaN
# ...

# %%
df.interpolate()
# Out:
#                                                 data                      \
# stats                                       atk_1_20 atk_20_20 atk_20_40
# id   character_name rarity region    vision
# 0    Albedo         5      Mondstadt Geo         NaN       NaN       NaN
# 1    Alhaitham      5      Sumeru    Dendro      NaN       NaN       NaN
# 3    Amber          4      Mondstadt Pyro        NaN       NaN       NaN
# 4    Arataki Itto   5      Inazuma   Geo         NaN       NaN       NaN
# 5    Baizhu         5      Liyue     Dendro      NaN       NaN       NaN
# ...                                              ...       ...       ...
# 3523 Yaoyao         4      Liyue     Dendro     20.0      51.0      67.0
# 3524 Yelan          5      Liyue     Hydro      20.0      51.0      67.0
# 3525 Yoimiya        5      Inazuma   Pyro       20.0      51.0      67.0
# 3526 Yun Jin        4      Liyue     Geo        20.0      51.0      67.0
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#          id character_name rarity     region  vision     data            \
# stats                                                atk_1_20 atk_20_20
# 0         0         Albedo      5  Mondstadt     Geo      NaN       NaN
# 1         1      Alhaitham      5     Sumeru  Dendro      NaN       NaN
# 2         3          Amber      4  Mondstadt    Pyro      NaN       NaN
# 3         4   Arataki Itto      5    Inazuma     Geo      NaN       NaN
# 4         5         Baizhu      5      Liyue  Dendro      NaN       NaN
# ...     ...            ...    ...        ...     ...      ...       ...
# 3376   3523         Yaoyao      4      Liyue  Dendro      NaN       NaN
# 3377   3524          Yelan      5      Liyue   Hydro      NaN       NaN
# 3378   3525        Yoimiya      5    Inazuma    Pyro      NaN       NaN
# 3379   3526        Yun Jin      4      Liyue     Geo      NaN       NaN
# 3380   3527        Zhongli      5      Liyue     Geo      NaN       NaN
#
# ...

# %%
import seaborn as sns

# %%
sns.histplot(x='region', y='vision', data=df)
# Out:
# <Axes: xlabel='region', ylabel='vision'>

# %%
sns.countplot(x='region', data=df)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.countplot(x='rarity', data=df)
# Out:
# <Axes: xlabel='rarity', ylabel='count'>

# %%
df.columns
# Out:
# MultiIndex([(            'id',           ''),
#             ('character_name',           ''),
#             (        'rarity',           ''),
#             (        'region',           ''),
#             (        'vision',           ''),
#             (          'data',   'atk_1_20'),
#             (          'data',  'atk_20_20'),
#             (          'data',  'atk_20_40'),
#             (          'data',  'atk_40_40'),
#             (          'data',  'atk_40_50'),
#             (          'data',  'atk_50_50'),
#             (          'data',  'atk_50_60'),
#             (          'data',  'atk_60_60'),
#             (          'data',  'atk_60_70'),
#             (          'data',  'atk_70_70'),
#             (          'data',  'atk_70_80'),
#             (          'data',  'atk_80_80'),
#             (          'data',  'atk_80_90'),
#             (          'data',  'atk_90_90'),
#             (          'data',   'def_1_20'),
# ...

# %%
df = pd.read_excel('../data/genshin.xlsx')
df
# Out:
#    character_name  rarity     region  vision weapon_type          model  \
# 0          Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1       Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2            Aloy       5        NaN    Cryo         Bow  Medium Female
# 3           Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4    Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ..            ...     ...        ...     ...         ...            ...
# 67         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 68          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 69        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 70        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 71        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#          constellation             birthday                   special_dish  \
# ...

# %%
df.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'hp_90_90', 'atk_90_90', 'def_90_90',
#        'hp_80_90', 'atk_80_90', 'def_80_90', 'hp_80_80', 'atk_80_80',
#        'def_80_80', 'hp_70_80', 'atk_70_80', 'def_70_80', 'hp_70_70',
#        'atk_70_70', 'def_70_70', 'hp_60_70', 'atk_60_70', 'def_60_70',
#        'hp_60_60', 'atk_60_60', 'def_60_60', 'hp_50_60', 'atk_50_60',
#        'def_50_60', 'hp_50_50', 'atk_50_50', 'def_50_50', 'hp_40_50',
#        'atk_40_50', 'def_40_50', 'hp_40_40', 'atk_40_40', 'def_40_40',
#        'hp_20_40', 'atk_20_40', 'def_20_40', 'hp_20_20', 'atk_20_20',
#        'def_20_20', 'hp_1_20', 'atk_1_20', 'def_1_20', 'spsecial_0',
# ...

# %%
layla = df[df['character_name'] == 'Layla']
layla
# Out:
#    character_name  rarity  region vision weapon_type          model  \
# 35          Layla       4  Sumeru   Cryo       Sword  Medium Female
#
#    constellation             birthday         special_dish affiliation  ...  \
# 35      Luscinia  2023-12-19 00:00:00  Extravagant Slumber   Rtawahist  ...
#
#    hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1 special_2 special_3  \
# 35     930       18       54          0         0      0.06      0.12
#
#    special_4 special_5 special_6
# 35      0.12      0.18      0.24
#
# [1 rows x 70 columns]

# %%
table = df['model'].str.split(' ')
table
df['size'] = table.str.get(0)
df['sex'] = table.str.get(1)

# %%
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df
# Out:
#    character_name  rarity     region  vision weapon_type          model  \
# 0          Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1       Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2            Aloy       5        NaN    Cryo         Bow  Medium Female
# 3           Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4    Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ..            ...     ...        ...     ...         ...            ...
# 67         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 68          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 69        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 70        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 71        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#          constellation             birthday                   special_dish  \
# ...

# %%
male = df[df['sex'] == 'Male']
female = df[df['sex'] == 'Female']

# %%
male.shape
# Out:
# (27, 72)

# %%
female.shape
# Out:
# (45, 72)

# %%
sns.histplot(x='sex', y='vision', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='vision'>

# %%
sns.countplot(y='affiliation', data=df)
# Out:
# <Axes: xlabel='count', ylabel='affiliation'>

# %%
sns.histplot(x='sex', y='affiliation', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='affiliation'>

# %%
sns.scatterplot(x='size', y='def_1_20', data=df)
# Out:
# <Axes: xlabel='size', ylabel='def_1_20'>

# %%
sns.histplot(x='sex', y='size', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='size'>

# %%
sns.histplot(x='model', y='region', data=df)
# Out:
# <Axes: xlabel='model', ylabel='region'>

# %%
sns.countplot(x='model', data=df)
# Out:
# <Axes: xlabel='model', ylabel='count'>

# %%
sns.boxplot(x='character_name', y='def_20_40', data=df)
# Out:
# <Axes: xlabel='character_name', ylabel='def_20_40'>

# %%
df['ascension_boss']
# Out:
# 0         Basalt Pillar
# 1        Pseudo-Stamens
# 2     Crystalline Bloom
# 3        Everflame Seed
# 4      Riftborn Regalia
#             ...
# 67      Quelled Creeper
# 68           Runic Fang
# 69     Smoldering Pearl
# 70     Riftborn Regalia
# 71        Basalt Pillar
# Name: ascension_boss, Length: 72, dtype: object

# %%
df[df['character_name'] == 'Lumine']
# Out:
# Empty DataFrame
# Columns: [character_name, rarity, region, vision, weapon_type, model, constellation, birthday, special_dish, affiliation, voice_eng, voice_cn, voice_jp, voice_kr, release_date, ascension, ascension_specialty, ascension_talent, ascension_boss, talent_book, talent_weekly, hp_90_90, atk_90_90, def_90_90, hp_80_90, atk_80_90, def_80_90, hp_80_80, atk_80_80, def_80_80, hp_70_80, atk_70_80, def_70_80, hp_70_70, atk_70_70, def_70_70, hp_60_70, atk_60_70, def_60_70, hp_60_60, atk_60_60, def_60_60, hp_50_60, atk_50_60, def_50_60, hp_50_50, atk_50_50, def_50_50, hp_40_50, atk_40_50, def_40_50, hp_40_40, atk_40_40, def_40_40, hp_20_40, atk_20_40, def_20_40, hp_20_20, atk_20_20, def_20_20, hp_1_20, atk_1_20, def_1_20, spsecial_0, special_1, special_2, special_3, special_4, special_5, special_6]
# Index: []
#
# [0 rows x 70 columns]

# %%
df[df['character_name'] == 'Layla']
# Out:
#    character_name  rarity  region vision weapon_type          model  \
# 35          Layla       4  Sumeru   Cryo       Sword  Medium Female
#
#    constellation             birthday         special_dish affiliation  ...  \
# 35      Luscinia  2023-12-19 00:00:00  Extravagant Slumber   Rtawahist  ...
#
#    hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1 special_2 special_3  \
# 35     930       18       54          0         0      0.06      0.12
#
#    special_4 special_5 special_6
# 35      0.12      0.18      0.24
#
# [1 rows x 70 columns]

# %%
df['ascension_talent']
# Out:
# 0        Divining Scroll
# 1        Faded Red Satin
# 2          Spectral Husk
# 3         Firm Arrowhead
# 4       Slime Condensate
#              ...
# 67      Slime Condensate
# 68    Recruit's Insignia
# 69       Divining Scroll
# 70          Damaged Mask
# 71      Slime Condensate
# Name: ascension_talent, Length: 72, dtype: object

# %%
df.head(1)
# Out:
#   character_name  rarity     region vision weapon_type        model  \
# 0         Albedo       5  Mondstadt    Geo       Sword  Medium Male
#
#         constellation             birthday    special_dish  \
# 0  Princeps Cretaceus  2023-09-13 00:00:00  Woodland Dream
#
#            affiliation  ... hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1  \
# 0  Knights of Favonius  ...    1030       20       68          0         0
#
#   special_2 special_3 special_4 special_5 special_6
# 0     0.072     0.144     0.144     0.216     0.288
#
# [1 rows x 70 columns]

# %%
sns.histplot(x='vision', y='hp_1_20', data=df)
# Out:
# <Axes: xlabel='vision', ylabel='hp_1_20'>

# %%
sns.displot(df['hp_1_20'])

# %%
sns.histplot(x='vision', y='weapon_type', data=df)
# Out:
# <Axes: xlabel='vision', ylabel='weapon_type'>

# %%
ax = sns.histplot(x='region', y='affiliation', data=df)

# %%
sns.histplot(x='region', y='weapon_type', data=df)
# Out:
# <Axes: xlabel='region', ylabel='weapon_type'>

# %%
sns.histplot(x='region', y='rarity', data=df)
# Out:
# <Axes: xlabel='region', ylabel='rarity'>
