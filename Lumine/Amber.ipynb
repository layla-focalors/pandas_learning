# %%
import pandas as pd

# %%
import os
os.listdir('../data')
# Out:
# ['banklist.csv',
#  'billboard.csv',
#  'concat_1.csv',
#  'concat_2.csv',
#  'concat_3.csv',
#  'country_timeseries.csv',
#  'gapminder.tsv',
#  'genshin.csv',
#  'genshin.xlsx',
#  'hypernetwork_loss.csv',
#  'pew.csv',
#  'print_data.xls',
#  'raw_data_urls.txt',
#  'scientists.csv',
#  'survey_person.csv',
#  'survey_site.csv',
#  'survey_survey.csv',
#  'survey_visited.csv',
#  'tesla_stock_quandl.csv',
#  'weather.csv']

# %%
df.shape
# Out:
# (72, 70)

# %%
df.loc[40:72]
# Out:
#         character_name  rarity     region   vision weapon_type          model  \
# 40                Mona       5  Mondstadt    Hydro    Catalyst  Medium Female
# 41              Nahida       5     Sumeru   Dendro    Catalyst   Short Female
# 42               Nilou       5     Sumeru    Hydro       Sword  Medium Female
# 43           Ningguang       4      Liyue      Geo    Catalyst    Tall Female
# 44              Noelle       4  Mondstadt      Geo    Claymore  Medium Female
# 45                Qiqi       5      Liyue     Cryo       Sword   Short Female
# 46       Raiden Shogun       5    Inazuma  Electro     Polearm    Tall Female
# 47               Razor       4  Mondstadt  Electro    Claymore    Medium Male
# 48             Rosaria       4  Mondstadt     Cryo     Polearm    Tall Female
# 49  Sangonomiya Kokomi       5    Inazuma    Hydro    Catalyst  Medium Female
# 50                Sayu       4    Inazuma    Anemo    Claymore   Short Female
# ...

# %%
df.head(72)
# Out:
#    character_name  rarity     region  vision weapon_type          model  \
# 0          Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1       Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2            Aloy       5        NaN    Cryo         Bow  Medium Female
# 3           Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4    Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ..            ...     ...        ...     ...         ...            ...
# 67         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 68          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 69        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 70        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 71        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#          constellation             birthday                   special_dish  \
# ...

# %%
df.head(30)
# Out:
#       character_name  rarity     region   vision weapon_type          model  \
# 0             Albedo       5  Mondstadt      Geo       Sword    Medium Male
# 1          Alhaitham       5     Sumeru   Dendro       Sword      Tall Male
# 2               Aloy       5        NaN     Cryo         Bow  Medium Female
# 3              Amber       4  Mondstadt     Pyro         Bow  Medium Female
# 4       Arataki Itto       5    Inazuma      Geo    Claymore      Tall Male
# 5             Baizhu       5      Liyue   Dendro    Catalyst      Tall Male
# 6            Barbara       4  Mondstadt    Hydro    Catalyst  Medium Female
# 7             Beidou       4      Liyue  Electro    Claymore    Tall Female
# 8            Bennett       4  Mondstadt     Pyro       Sword    Medium Male
# 9            Candace       4     Sumeru    Hydro     Polearm    Tall Female
# 10          Chongyun       4      Liyue     Cryo    Claymore    Medium Male
# ...

# %%
df = pd.read_excel('../data/genshin.xlsx')
df.head()
# Out:
#   character_name  rarity     region  vision weapon_type          model  \
# 0         Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1      Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2           Aloy       5        NaN    Cryo         Bow  Medium Female
# 3          Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4   Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
#
#         constellation             birthday                special_dish  \
# 0  Princeps Cretaceus  2023-09-13 00:00:00              Woodland Dream
# 1       Vultur Volans  2023-02-11 00:00:00          Ideal Circumstance
# 2         Nora Fortis  2023-04-04 00:00:00                 Satiety Gel
# 3               Lepus  2023-08-10 00:00:00  Outrider's Champion Steak!
# 4    Taurus Iracundus  2023-06-01 00:00:00           Way of the Strong
#
#            affiliation  ... hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1  \
# ...

# %%
df['character_name']
# Out:
# 0           Albedo
# 1        Alhaitham
# 2             Aloy
# 3            Amber
# 4     Arataki Itto
#           ...
# 67          Yaoyao
# 68           Yelan
# 69         Yoimiya
# 70         Yun Jin
# 71         Zhongli
# Name: character_name, Length: 72, dtype: object
