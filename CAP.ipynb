# %%
import seaborn as sns
df = sns.load_dataset("tips")
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxenplot
# Out:
# <function seaborn.categorical.boxenplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, k_depth='tukey', linewidth=None, scale='exponential', outlier_prop=0.007, trust_alpha=0.05, showfliers=True, ax=None, box_kws=None, flier_kws=None, line_kws=None)>

# %%
sns.boxenplot(x="day", y="total_bill", hue='sex', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# tab 키 누르면 자동완성
sns.catplot
# Out:
# <function seaborn.categorical.catplot(data=None, *, x=None, y=None, hue=None, row=None, col=None, col_wrap=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, height=5, aspect=1, kind='strip', native_scale=False, formatter=None, orient=None, color=None, palette=None, hue_norm=None, legend='auto', legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, ci='deprecated', **kwargs)>

# %%
sns.catplot(x="total_bill", data=df)

# %%
import os
os.chdir('./')
os.listdir('./')
os.system('git add .')
# Out:
# 0

# %%
os.system('git commit -m "jupyter commit"')
# Out:
# 0

# %%
os.system('git status')
# Out:
# 0
