# %%
# 1
import pandas as pd

# %%
df = pd.read_csv('../data/gapminder.tsv', sep='\t')
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# 4.
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country_df = df['country']
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
print(type(country_df))
country_df.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df.loc[:,['country','continent','year']]
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
subset = df[['country','continent','year']]
subset
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
# index 출력
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.loc[df.shape[0] - 1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.tail(1)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[[0,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.iloc[[0,99,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df.loc[:, ['year','pop']]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
df.iloc[:, [2, 4, -1]]
# Out:
#       year       pop   gdpPercap
# 0     1952   8425333  779.445314
# 1     1957   9240934  820.853030
# 2     1962  10267083  853.100710
# 3     1967  11537966  836.197138
# 4     1972  13079460  739.981106
# ...    ...       ...         ...
# 1699  1987   9216418  706.157306
# 1700  1992  10704340  693.420786
# 1701  1997  11404948  792.449960
# 1702  2002  11926563  672.038623
# 1703  2007  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
rs = list(range(5))
df.iloc[:, list(range(5))]
# Out:
#           country continent  year  lifeExp       pop
# 0     Afghanistan      Asia  1952   28.801   8425333
# 1     Afghanistan      Asia  1957   30.332   9240934
# 2     Afghanistan      Asia  1962   31.997  10267083
# 3     Afghanistan      Asia  1967   34.020  11537966
# 4     Afghanistan      Asia  1972   36.088  13079460
# ...           ...       ...   ...      ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418
# 1700     Zimbabwe    Africa  1992   60.377  10704340
# 1701     Zimbabwe    Africa  1997   46.809  11404948
# 1702     Zimbabwe    Africa  2002   39.989  11926563
# 1703     Zimbabwe    Africa  2007   43.487  12311143
#
# [1704 rows x 5 columns]

# %%
df.iloc[list(range(0,6,2)), :]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.iloc[:, list(range(0, 6, 2))]
# Out:
#           country  year       pop
# 0     Afghanistan  1952   8425333
# 1     Afghanistan  1957   9240934
# 2     Afghanistan  1962  10267083
# 3     Afghanistan  1967  11537966
# 4     Afghanistan  1972  13079460
# ...           ...   ...       ...
# 1699     Zimbabwe  1987   9216418
# 1700     Zimbabwe  1992  10704340
# 1701     Zimbabwe  1997  11404948
# 1702     Zimbabwe  2002  11926563
# 1703     Zimbabwe  2007  12311143
#
# [1704 rows x 3 columns]

# %%
df.iloc[:3, :]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
df.iloc[:, :3]
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
df.iloc[:, 0:6:2]
# Out:
#           country  year       pop
# 0     Afghanistan  1952   8425333
# 1     Afghanistan  1957   9240934
# 2     Afghanistan  1962  10267083
# 3     Afghanistan  1967  11537966
# 4     Afghanistan  1972  13079460
# ...           ...   ...       ...
# 1699     Zimbabwe  1987   9216418
# 1700     Zimbabwe  1992  10704340
# 1701     Zimbabwe  1997  11404948
# 1702     Zimbabwe  2002  11926563
# 1703     Zimbabwe  2007  12311143
#
# [1704 rows x 3 columns]

# %%
df.iloc[[0,99,999], [0,3,5]]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
df.loc[[0,99,999], ['country','lifeExp','gdpPercap']]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %%
df.loc[10:13, ['country','lifeExp','gdpPercap']]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
df.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.iloc[0:10]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['lifeExp']

# %%
df.groupby(['year','continent'])['lifeExp','gdpPercap'].mean()
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\428816681.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['year','continent'])['lifeExp','gdpPercap'].mean()
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
# ...

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby('year')['lifeExp'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
s = pd.Series(['layla','focalors'])
s
# Out:
# 0       layla
# 1    focalors
# dtype: object

# %%
s = pd.Series(['layla','focalors'])
s.index=['cute','github dev']
s
# Out:
# cute             layla
# github dev    focalors
# dtype: object

# %%
df = pd.DataFrame({
    'Name' : ['Rosalin Franklin', 'William Gosset'],
    'Occupation' : ['Chemist', 'Statis'],
    'Born' : ['1920-07-25', '1876-06-13'],
    'Died' : ['1958-04-16', '1937-10-16'],
    'Age' : [37, 61]
})

# %%
df
# Out:
#                Name Occupation        Born        Died  Age
# 0  Rosalin Franklin    Chemist  1920-07-25  1958-04-16   37
# 1    William Gosset     Statis  1876-06-13  1937-10-16   61

# %%
df = pd.DataFrame({
    'Occupation' : ['Chemist', 'Statis'],
    'Born' : ['1920-07-25', '1876-06-13'],
    'Died' : ['1958-04-16', '1937-10-16'],
    'Age' : [37, 61]
}, index=['Rosalin Franklin', 'William Gosset'], columns=['Occupation','Born','Age','Died'])
df
# Out:
#                  Occupation        Born  Age        Died
# Rosalin Franklin    Chemist  1920-07-25   37  1958-04-16
# William Gosset       Statis  1876-06-13   61  1937-10-16

# %%
from collections import OrderedDict
df = pd.DataFrame(OrderedDict([
    ('Name', ['Rosalin Franklin', 'William Gosset']),
    ('Occupation', ['Chemist', 'Statis']),
    ('Born', ['1920-07-25', '1876-06-13']),
    ('Died', ['1958-04-16', '1937-10-16']),
    ('Age', [37, 61])
]))
df
# Out:
#                Name Occupation        Born        Died  Age
# 0  Rosalin Franklin    Chemist  1920-07-25  1958-04-16   37
# 1    William Gosset     Statis  1876-06-13  1937-10-16   61

# %%
sci = pd.read_csv('../data/scientists.csv')
scimk = sci['Name']
scimk.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
type(sci.loc[0])
# Out:
# pandas.core.series.Series

# %%
sci.loc[0].index
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation'], dtype='object')

# %%
sci.loc[0].keys()
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation'], dtype='object')

# %%
sci.loc[0].values
# Out:
# array(['Rosaline Franklin', '1920-07-25', '1958-04-16', 37, 'Chemist'],
#       dtype=object)

# %%
sci.loc[0].index[0]
# Out:
# 'Name'

# %%
sci.loc[0].keys()[0]
# Out:
# 'Name'

# %%
ages = df['Age']
print(ages.std())
print(ages.median())
print(ages.mean())
print(ages.min())
print(ages.max())
# Out:
# 16.97056274847714
# 49.0
# 49.0
# 37
# 61

# %%
ages.describe()
# Out:
# count     2.000000
# mean     49.000000
# std      16.970563
# min      37.000000
# 25%      43.000000
# 50%      49.000000
# 75%      55.000000
# max      61.000000
# Name: Age, dtype: float64

# %%
ages = df['Age']
df[ages > ages.mean()]
# Out:
#              Name Occupation        Born        Died  Age
# 1  William Gosset     Statis  1876-06-13  1937-10-16   61

# %%
df = sci

# %%
ages = df['Age']

# %%
ages[ages > ages.mean()]
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
df[df['Age'] > df['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
rule = [True, True, False, False, True, True, False, True]
df[rule]
# Out:
#                 Name        Born        Died  Age     Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37        Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61   Statistician
# 4      Rachel Carson  1907-05-27  1964-04-14   56      Biologist
# 5          John Snow  1813-03-15  1858-06-16   45      Physician
# 7       Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
ages + ages
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
ages * ages
# Out:
# 0    1369
# 1    3721
# 2    8100
# 3    4356
# 4    3136
# 5    2025
# 6    1681
# 7    5929
# Name: Age, dtype: int64

# %%
ages * 2
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
ages + 800
# Out:
# 0    837
# 1    861
# 2    890
# 3    866
# 4    856
# 5    845
# 6    841
# 7    877
# Name: Age, dtype: int64

# %%
st = ages.sort_index(ascending=False)
st
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
df[df['Age'] > df['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
bools = [True, True, False, True, True, True, False, True]
df[bools]
# Out:
#                 Name        Born        Died  Age     Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37        Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61   Statistician
# 3        Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56      Biologist
# 5          John Snow  1813-03-15  1858-06-16   45      Physician
# 7       Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
df.loc[bools]
# Out:
#                 Name        Born        Died  Age     Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37        Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61   Statistician
# 3        Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56      Biologist
# 5          John Snow  1813-03-15  1858-06-16   45      Physician
# 7       Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
df * 2
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %%
df[['Born','Died']].dtypes
# Out:
# Born    object
# Died    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 452.0+ bytes

# %%
df['born_new'] = pd.to_datetime(df['Born'], format='%Y-%m-%d')
df['died_new'] = pd.to_datetime(df['Died'], format='%Y-%m-%d')

# %%
df[['born_new','died_new']].dtypes
# Out:
# born_new    datetime64[ns]
# died_new    datetime64[ns]
# dtype: object

# %%
df['lifeExp'] = df['died_new'] - df['born_new']
df['age_ new'] = df['lifeExp'] / 365
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#     born_new   died_new    lifeExp                   age_ new
# 0 1920-07-25 1958-04-16 13779 days 37 days 18:00:59.178082191
# 1 1876-06-13 1937-10-16 22404 days 61 days 09:08:23.013698630
# 2 1820-05-12 1910-08-13 32964 days 90 days 07:29:45.205479452
# 3 1867-11-07 1934-07-04 24345 days 66 days 16:46:01.643835616
# ...

# %%
import random
random.shuffle(df['Age'])
df
# Out:
# C:\Users\starl\anaconda3\Lib\random.py:383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   61             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   45        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   56               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   41             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   77           Biologist
# 5             John Snow  1813-03-15  1858-06-16   37           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   66  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   90       Mathematician
#
# ...

# %%
df = df.drop('Age', axis=1)

# %%
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#     born_new   died_new    lifeExp                   age_ new
# 0 1920-07-25 1958-04-16 13779 days 37 days 18:00:59.178082191
# 1 1876-06-13 1937-10-16 22404 days 61 days 09:08:23.013698630
# 2 1820-05-12 1910-08-13 32964 days 90 days 07:29:45.205479452
# 3 1867-11-07 1934-07-04 24345 days 66 days 16:46:01.643835616
# ...

# %%
df.to_pickle('./df.pickle')

# %%
import os
os.listdir('./')
# Out:
# ['.ipynb_checkpoints', 'Case1.ipynb', 'df.pickle']

# %%
df = pd.read_pickle('./df.pickle')
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#     born_new   died_new    lifeExp                   age_ new
# 0 1920-07-25 1958-04-16 13779 days 37 days 18:00:59.178082191
# 1 1876-06-13 1937-10-16 22404 days 61 days 09:08:23.013698630
# 2 1820-05-12 1910-08-13 32964 days 90 days 07:29:45.205479452
# 3 1867-11-07 1934-07-04 24345 days 66 days 16:46:01.643835616
# ...

# %%
df.to_csv('./df.csv')
df.to_csv('./df.tsv', sep='\t')

# %%
import os
os.listdir('./')
# Out:
# ['.ipynb_checkpoints', 'Case1.ipynb', 'df.csv', 'df.pickle', 'df.tsv']

# %%
import xlwt
import openpyxl
df.to_excel('./df.xls')
df.to_excel('./df.xlsx')
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\3616480007.py:3: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('./df.xls')

# %%
import os
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  'Case1.ipynb',
#  'df.csv',
#  'df.pickle',
#  'df.tsv',
#  'df.xls',
#  'df.xlsx']

# %%
import seaborn as sns
df = sns.load_dataset('anscombe')
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
ax = sns.PairGrid(data=df)

# %%
sns.lmplot(x='x', y='y', data=df, fit_reg=False)

# %%
dataset1 = df[df['dataset'] == 'I']
dataset2 = df[df['dataset'] == 'II']
dataset3 = df[df['dataset'] == 'III']
dataset4 = df[df['dataset'] == 'IV']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.scatter(dataset1['x'], dataset1['y'])
ax2.scatter(dataset2['x'], dataset2['y'])
ax3.scatter(dataset3['x'], dataset3['y'])
ax4.scatter(dataset4['x'], dataset4['y'])

ax1.set_title('gr1')
ax2.set_title('gr2')
ax3.set_title('gr3')
ax4.set_title('gr4')
fig.suptitle('da')
fig.tight_layout()

# %%
plt.tight_layout()

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.hist(df['total_bill'])
ax.set_xlabel('frquency')
ax.set_ylabel('total_bill')
ax.set_title('Histogram of total bill')
# Out:
# Text(0.5, 1.0, 'Histogram of total bill')

# %%
sd = sns.distplot(df['total_bill'], kde=False)
sd.set_xlabel('frequency')
sd.set_ylabel('total_bill')
sd.set_title('Histogram of Total bill')
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\614923864.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sd = sns.distplot(df['total_bill'], kde=False)
# Text(0.5, 1.0, 'Histogram of Total bill')

# %%
fig = plt.figure()
ap = fig.add_subplot(1,1,1)
ap.scatter(df['total_bill'], y=df['tip'])
ap.set_xlabel('total_bill')
ap.set_ylabel('tip')
ap.set_title('total_bill & tip')
# Out:
# Text(0.5, 1.0, 'total_bill & tip')

# %%
ss = sns.scatterplot(x='total_bill', y='tip', data=df, marker='*', color='pink')
ss.set_xlabel('total_bill')
ss.set_ylabel('tip')
ss.set_title('total bill & tip')
# Out:
# Text(0.5, 1.0, 'total bill & tip')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.boxplot([df[df['sex'] == 'Female']['tip'],
             df[df['sex'] == 'Male']['tip']], labels=['Female', 'Male'])
ax.set_xlabel('sex')
ax.set_ylabel('tip')
ax.set_title('sex & tips')
# Out:
# Text(0.5, 1.0, 'sex & tips')

# %%
xx = sns.boxplot(x='sex', y='tip', data=df)
xx.set_title('sex & tips')
# Out:
# Text(0.5, 1.0, 'sex & tips')

# %%
def secpp(sex):
    if(sex) == 'Female':
        return 1
    else:
        return 0

# %%
df['sex_color'] = df['sex'].apply(secpp)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=df, size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x=df['total_bill'], y=df['tip'], c=df['sex_color'], s=df['size'] * 10)
ax.set_xlabel('total_bill')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
ax = sns.distplot(df['total_bill'], kde=False)
ax.set_xlabel('total_bill')
ax.set_ylabel('frequency')
ax.set_title('histogram')
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\829921502.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['total_bill'], kde=False)
# Text(0.5, 1.0, 'histogram')

# %%
ax = sns.distplot(df['total_bill'], rug=True, hist=False, kde=False)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\531842526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['total_bill'], rug=True, hist=False, kde=False)

# %%
ax = sns.distplot(df['total_bill'], hist=False)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\4147324913.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['total_bill'], hist=False)

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x='total_bill', y='tip', data=df, fill=True, shade=True)
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_45456\2960329038.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='total_bill', y='tip', data=df, fill=True, shade=True)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1

# %%
obje = ['Thur', 'Fri', 'Sat', 'Sun']
plt.bar(obje, df['day'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[226], line 2
#       1 obje = ['Thur', 'Fri', 'Sat', 'Sun']
# ----> 2 plt.bar(obje, df['day'])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# ...

# %%
sns.countplot(x=df['day'], data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.regplot(x='total_bill', y='tip', data=df, fit_reg=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
ax = sns.jointplot(x='total_bill', y='tip', data=df, kind='hex', color='pink')
ax.set_axis_labels(xlabel='total_bill', ylabel='tip')

# %%
sns.kdeplot(x='total_bill', y='tip', data=df, fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1

# %%
sns.barplot(x='time', y='total_bill', data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.countplot(x='time', y='total_bill', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 sns.countplot(x='time', y='total_bill', data=df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2941, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939     y = x
#    2940 elif x is not None and y is not None:
# -> 2941     raise ValueError("Cannot pass values for both `x` and `y`")
#    2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
sns.boxplot(x='time', y='total_bill', data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(x='time', y='total_bill', data=df)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(df)

# %%
nx = sns.pairplot(df)
nx.map_upper(sns.regplot)
nx.map_lower(sns.kdeplot)
nx.map_diag(sns.distplot, rug=True, hist=False)
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 sns.pairplot()
#
# TypeError: pairplot() missing 1 required positional argument: 'data'

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax = sns.pairplot(df)
ax.map_upper(sns.kdeplot)
ax.map_lower(sns.boxplot)
ax.map_diag(sns.distplot)
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.violinplot(x='time', y='total_bill', hue='sex', data=df, split=True)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill', y='tip', data=df, fit_reg=False)

# %%
sns.pairplot(df, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=df, fit_reg=False)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', markers=['o','*'], data=df, fit_reg=False)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', markers=['O', 'star'], data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.scatterplot(x='x', y='y', data=anscombe, col='dataset', col_wrap=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[287], line 1
# ----> 1 sns.scatterplot(x='x', y='y', data=anscombe, col='dataset', col_wrap=2)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:759, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     756 # Other functions have color as an explicit param,
#     757 # and we should probably do that here too
#     758 color = kwargs.pop("color", None)
# --> 759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     761 p.plot(ax, kwargs)
#     763 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:122, in _default_color(method, hue, color, kws)
#     116 scout_size = max(
#     117     np.atleast_1d(kws.get(key, [])).shape[0]
# ...

# %%
anscombe = sns.load_dataset('anscombe')
sns.lmplot(x='x', y='y', data=anscombe, col='dataset', col_wrap=2, fit_reg=False)

# %%
df
dfa = sns.load_dataset('anscombe')
dfa
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
facet = sns.FacetGrid(dfa, col='dataset')
facet.map(sns.lmplot, x='x', y='y', data=dfa, col_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[294], line 2
#       1 facet = sns.FacetGrid(dfa, col='dataset')
# ----> 2 facet.map(sns.lmplot, x='x', y='y', data=dfa)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:752, in FacetGrid.map(self, func, *args, **kwargs)
#     749         plot_args = [v.values for v in plot_args]
#     751     # Draw the plot
# --> 752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
#     755 self._finalize_grid(args[:2])
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# ...

# %%
facet = sns.FacetGrid(df, col='time')
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1

# %%
facet = sns.FacetGrid(df, col='day')
facet.map(sns.distplot, 'total_bill')
facet = facet.add_legend()
# Out:
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\starl\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
fig, ax = plt.subplots(ncols=2)
sns.scatterplot("total_bill", "tip", data=df, ax=ax[0])
sns.stripplot("size", "tip", data=df, ax=ax[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[306], line 2
#       1 fig, ax = plt.subplots(ncols=2)
# ----> 2 sns.scatterplot("total_bill", "tip", data=df, ax=ax[0])
#       3 sns.stripplot("size", "tip", data=df, ax=ax[1])
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
fig, ax = plt.subplot(1, 2, 2)
sns.histplot(x='total_bill', y='tip', data=df, ax=ax[0])
sns.boxplot(x='sex', y='tip', data=df, ax=ax[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[305], line 1
# ----> 1 fig, ax = plt.subplot(1, 2, 2)
#       2 sns.histplot(x='total_bill', y='tip', data=df, ax=ax[0])
#       3 sns.boxplot(x='sex', y='tip', data=df, ax=ax[1])
#
# TypeError: cannot unpack non-iterable Axes object
