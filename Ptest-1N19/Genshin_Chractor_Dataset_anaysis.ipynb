# %%
import os
os.listdir('../data')
# Out:
# ['banklist.csv',
#  'billboard.csv',
#  'concat_1.csv',
#  'concat_2.csv',
#  'concat_3.csv',
#  'country_timeseries.csv',
#  'gapminder.tsv',
#  'genshin.csv',
#  'pew.csv',
#  'raw_data_urls.txt',
#  'scientists.csv',
#  'survey_person.csv',
#  'survey_site.csv',
#  'survey_survey.csv',
#  'survey_visited.csv',
#  'tesla_stock_quandl.csv',
#  'weather.csv']

# %%
import pandas as pd
df = pd.read_csv('../data/tesla_stock_quandl.csv')
df.head()
# Out:
#          Date    Open    High     Low   Close      Volume  ExDividend  \
# 0  2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1  2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2  2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3  2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4  2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
df = pd.read_csv('../data/country_timeseries.csv')
df
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
df.isnull().sum()
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
df.shape
# Out:
# (122, 18)

# %%
df.isnull().sum()
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# ExDividend    0
# SplitRatio    0
# AdjOpen       0
# AdjHigh       0
# AdjLow        0
# AdjClose      0
# AdjVolume     0
# dtype: int64

# %%
df = pd.read_csv('../data/genshin.csv', encoding='utf-8')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1083, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1233, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1246, in pandas._libs.parsers.TextReader._string_convert()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\parsers.pyx:1444, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 11: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv('../data/genshin.csv', encoding='utf-8')
#       2 df
#
# ...

# %%
df = pd.read_excel('../data/genshin.xlsx')
df.head()
# Out:
#   character_name  rarity     region  vision weapon_type          model  \
# 0         Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1      Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2           Aloy       5        NaN    Cryo         Bow  Medium Female
# 3          Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4   Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
#
#         constellation             birthday                special_dish  \
# 0  Princeps Cretaceus  2023-09-13 00:00:00              Woodland Dream
# 1       Vultur Volans  2023-02-11 00:00:00          Ideal Circumstance
# 2         Nora Fortis  2023-04-04 00:00:00                 Satiety Gel
# 3               Lepus  2023-08-10 00:00:00  Outrider's Champion Steak!
# 4    Taurus Iracundus  2023-06-01 00:00:00           Way of the Strong
#
#            affiliation  ... hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1  \
# ...

# %%
df.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'hp_90_90', 'atk_90_90', 'def_90_90',
#        'hp_80_90', 'atk_80_90', 'def_80_90', 'hp_80_80', 'atk_80_80',
#        'def_80_80', 'hp_70_80', 'atk_70_80', 'def_70_80', 'hp_70_70',
#        'atk_70_70', 'def_70_70', 'hp_60_70', 'atk_60_70', 'def_60_70',
#        'hp_60_60', 'atk_60_60', 'def_60_60', 'hp_50_60', 'atk_50_60',
#        'def_50_60', 'hp_50_50', 'atk_50_50', 'def_50_50', 'hp_40_50',
#        'atk_40_50', 'def_40_50', 'hp_40_40', 'atk_40_40', 'def_40_40',
#        'hp_20_40', 'atk_20_40', 'def_20_40', 'hp_20_20', 'atk_20_20',
#        'def_20_20', 'hp_1_20', 'atk_1_20', 'def_1_20', 'spsecial_0',
# ...

# %%
df_u = pd.melt(df, id_vars=['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model', 'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng', 'voice_cn', 'voice_jp', 'voice_kr','release_date', 'ascension', 'ascension_specialty','ascension_talent', 'ascension_boss', 'talent_book', 'talent_weekly'], value_name="level", var_name="stats")

# %%
df_u
# Out:
#      character_name  rarity     region  vision weapon_type          model  \
# 0            Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1         Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2              Aloy       5     Sumeru    Cryo         Bow  Medium Female
# 3             Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4      Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ...             ...     ...        ...     ...         ...            ...
# 3523         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 3524          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 3525        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 3526        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 3527        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#            constellation             birthday                   special_dish  \
# ...

# %%
df.isnull().sum()
# Out:
# character_name    0
# rarity            0
# region            3
# vision            0
# weapon_type       0
#                  ..
# special_2         0
# special_3         0
# special_4         0
# special_5         0
# special_6         0
# Length: 70, dtype: int64

# %%
df_u = df_u.fillna(method='ffill')
df_u
# Out:
#      character_name  rarity     region  vision weapon_type          model  \
# 0            Albedo       5  Mondstadt     Geo       Sword    Medium Male
# 1         Alhaitham       5     Sumeru  Dendro       Sword      Tall Male
# 2              Aloy       5     Sumeru    Cryo         Bow  Medium Female
# 3             Amber       4  Mondstadt    Pyro         Bow  Medium Female
# 4      Arataki Itto       5    Inazuma     Geo    Claymore      Tall Male
# ...             ...     ...        ...     ...         ...            ...
# 3523         Yaoyao       4      Liyue  Dendro     Polearm   Short Female
# 3524          Yelan       5      Liyue   Hydro         Bow    Tall Female
# 3525        Yoimiya       5    Inazuma    Pyro         Bow  Medium Female
# 3526        Yun Jin       4      Liyue     Geo     Polearm  Medium Female
# 3527        Zhongli       5      Liyue     Geo     Polearm      Tall Male
#
#            constellation             birthday                   special_dish  \
# ...

# %%
df_u.columns
# Out:
# Index(['character_name', 'rarity', 'region', 'vision', 'weapon_type', 'model',
#        'constellation', 'birthday', 'special_dish', 'affiliation', 'voice_eng',
#        'voice_cn', 'voice_jp', 'voice_kr', 'release_date', 'ascension',
#        'ascension_specialty', 'ascension_talent', 'ascension_boss',
#        'talent_book', 'talent_weekly', 'stats', 'level'],
#       dtype='object')

# %%
df[df['rarity'] == 5]
# Out:
#         character_name  rarity     region   vision weapon_type          model  \
# 0               Albedo       5  Mondstadt      Geo       Sword    Medium Male
# 1            Alhaitham       5     Sumeru   Dendro       Sword      Tall Male
# 2                 Aloy       5     Sumeru     Cryo         Bow  Medium Female
# 4         Arataki Itto       5    Inazuma      Geo    Claymore      Tall Male
# 5               Baizhu       5      Liyue   Dendro    Catalyst      Tall Male
# 12                Cyno       5     Sumeru  Electro     Polearm    Medium Male
# 13               Dehya       5     Sumeru     Pyro    Claymore    Tall Female
# 14               Diluc       5  Mondstadt     Pyro    Claymore      Tall Male
# 17                Eula       5  Mondstadt     Cryo    Claymore    Tall Female
# 21               Ganyu       5      Liyue     Cryo         Bow  Medium Female
# 23              Hu Tao       5      Liyue     Pyro     Polearm  Medium Female
# ...

# %%
df[df['character_name'] == 'Eula']
# Out:
#    character_name  rarity     region vision weapon_type        model  \
# 17           Eula       5  Mondstadt   Cryo    Claymore  Tall Female
#
#    constellation             birthday    special_dish          affiliation  \
# 17  Aphros Delos  2023-10-25 00:00:00  Stormcrest Pie  Knights of Favonius
#
#     ... hp_1_20 atk_1_20 def_1_20 spsecial_0 special_1 special_2 special_3  \
# 17  ...    1030       27       58          0         0     0.096     0.192
#
#    special_4 special_5 special_6
# 17     0.192     0.288     0.384
#
# [1 rows x 70 columns]
